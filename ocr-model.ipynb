# %% [markdown]
# # Скачивание датасета

# %%
# !wget https://storage.yandexcloud.net/datasouls-competitions/ai-nto-final-2022/data.zip
# Out:
# --2022-10-29 20:10:28--  https://storage.yandexcloud.net/datasouls-competitions/ai-nto-final-2022/data.zip
# Resolving storage.yandexcloud.net (storage.yandexcloud.net)... 213.180.193.243, 2a02:6b8::1d9
# Connecting to storage.yandexcloud.net (storage.yandexcloud.net)|213.180.193.243|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6370765510 (5.9G) [application/zip]
# Saving to: ‘data.zip’
#
# data.zip            100%[===================>]   5.93G  20.7MB/s    in 5m 1s
#
# 2022-10-29 20:15:30 (20.2 MB/s) - ‘data.zip’ saved [6370765510/6370765510]

# %%
# !unzip /content/data.zip
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
#   inflating: __MACOSX/data/train_recognition/images/._125268.png
#   inflating: data/train_recognition/images/21046.png
#   inflating: __MACOSX/data/train_recognition/images/._21046.png
#   inflating: data/train_recognition/images/84388.png
#   inflating: __MACOSX/data/train_recognition/images/._84388.png
#   inflating: data/train_recognition/images/2904.png
#   inflating: __MACOSX/data/train_recognition/images/._2904.png
#   inflating: data/train_recognition/images/37624.png
#   inflating: __MACOSX/data/train_recognition/images/._37624.png
#   inflating: data/train_recognition/images/71671.png
#   inflating: __MACOSX/data/train_recognition/images/._71671.png
#   inflating: data/train_recognition/images/85096.png
#   inflating: __MACOSX/data/train_recognition/images/._85096.png
#   inflating: data/train_recognition/images/20358.png
#   inflating: __MACOSX/data/train_recognition/images/._20358.png
#   inflating: data/train_recognition/images/124176.png
#   inflating: __MACOSX/data/train_recognition/images/._124176.png
#   inflating: data/train_recognition/images/38517.png
#   inflating: __MACOSX/data/train_recognition/images/._38517.png
#   inflating: data/train_recognition/images/61462.png
#   inflating: __MACOSX/data/train_recognition/images/._61462.png
#   inflating: data/train_recognition/images/27437.png
#   inflating: __MACOSX/data/train_recognition/images/._27437.png
#   inflating: data/train_recognition/images/123619.png
#   inflating: __MACOSX/data/train_recognition/images/._123619.png
#   inflating: data/train_recognition/images/28704.png
#   inflating: __MACOSX/data/train_recognition/images/._28704.png
#   inflating: data/train_recognition/images/16832.png
#   inflating: __MACOSX/data/train_recognition/images/._16832.png
#   inflating: data/train_recognition/images/134365.png
#   inflating: __MACOSX/data/train_recognition/images/._134365.png
#   inflating: data/train_recognition/images/50867.png
#   inflating: __MACOSX/data/train_recognition/images/._50867.png
#   inflating: data/train_recognition/images/95285.png
#   inflating: __MACOSX/data/train_recognition/images/._95285.png
#   inflating: data/train_recognition/images/7307_eng.png
#   inflating: data/train_recognition/images/741.png
#   inflating: __MACOSX/data/train_recognition/images/._741.png
#   inflating: data/train_recognition/images/33442.png
#   inflating: __MACOSX/data/train_recognition/images/._33442.png
#   inflating: data/train_recognition/images/146095.png
#   inflating: __MACOSX/data/train_recognition/images/._146095.png
#   inflating: data/train_recognition/images/87859.png
#   inflating: __MACOSX/data/train_recognition/images/._87859.png
#   inflating: data/train_recognition/images/75417.png
#   inflating: __MACOSX/data/train_recognition/images/._75417.png
#   inflating: data/train_recognition/images/44812.png
#   inflating: __MACOSX/data/train_recognition/images/._44812.png
#   inflating: data/train_recognition/images/5567_eng.png
#   inflating: data/train_recognition/images/120310.png
#   inflating: __MACOSX/data/train_recognition/images/._120310.png
#   inflating: data/train_recognition/images/13792.png
#   inflating: __MACOSX/data/train_recognition/images/._13792.png
#   inflating: data/train_recognition/images/65604.png
#   inflating: __MACOSX/data/train_recognition/images/._65604.png
#   inflating: data/train_recognition/images/9689.png
#   inflating: __MACOSX/data/train_recognition/images/._9689.png
#   inflating: data/train_recognition/images/23651.png
#   inflating: __MACOSX/data/train_recognition/images/._23651.png
#   inflating: data/train_recognition/images/32984.png
#   inflating: __MACOSX/data/train_recognition/images/._32984.png
#   inflating: data/train_recognition/images/98979.png
#   inflating: __MACOSX/data/train_recognition/images/._98979.png
#   inflating: data/train_recognition/images/72378.png
#   inflating: __MACOSX/data/train_recognition/images/._72378.png
#   inflating: data/train_recognition/images/139899.png
#   inflating: __MACOSX/data/train_recognition/images/._139899.png
#   inflating: data/train_recognition/images/130103.png
#   inflating: __MACOSX/data/train_recognition/images/._130103.png
#   inflating: data/train_recognition/images/87681.png
#   inflating: __MACOSX/data/train_recognition/images/._87681.png
#   inflating: data/train_recognition/images/118857.png
#   inflating: __MACOSX/data/train_recognition/images/._118857.png
#   inflating: data/train_recognition/images/126761.png
#   inflating: __MACOSX/data/train_recognition/images/._126761.png
#   inflating: data/train_recognition/images/999.png
#   inflating: __MACOSX/data/train_recognition/images/._999.png
#   inflating: data/train_recognition/images/96954.png
#   inflating: __MACOSX/data/train_recognition/images/._96954.png
#   inflating: data/train_recognition/images/109782.png
#   inflating: __MACOSX/data/train_recognition/images/._109782.png
#   inflating: data/train_recognition/images/8597.png
#   inflating: __MACOSX/data/train_recognition/images/._8597.png
#   inflating: data/train_recognition/images/35033.png
#   inflating: __MACOSX/data/train_recognition/images/._35033.png
#   inflating: data/train_recognition/images/73066.png
#   inflating: __MACOSX/data/train_recognition/images/._73066.png
#   inflating: data/train_recognition/images/129452.png
#   inflating: __MACOSX/data/train_recognition/images/._129452.png
#   inflating: data/train_recognition/images/74709.png
#   inflating: __MACOSX/data/train_recognition/images/._74709.png
#   inflating: data/train_recognition/images/9851.png
#   inflating: __MACOSX/data/train_recognition/images/._9851.png
#   inflating: data/train_recognition/images/136572.png
#   inflating: __MACOSX/data/train_recognition/images/._136572.png
#   inflating: data/train_recognition/images/10300_eng.png
#   inflating: data/train_recognition/images/119591.png
#   inflating: __MACOSX/data/train_recognition/images/._119591.png
#   inflating: data/train_recognition/images/97492.png
#   inflating: __MACOSX/data/train_recognition/images/._97492.png
#   inflating: data/train_recognition/images/23889.png
#   inflating: __MACOSX/data/train_recognition/images/._23889.png
#   inflating: data/train_recognition/images/63275.png
#   inflating: __MACOSX/data/train_recognition/images/._63275.png
#   inflating: data/train_recognition/images/139641.png
#   inflating: __MACOSX/data/train_recognition/images/._139641.png
#   inflating: data/train_recognition/images/89874.png
#   inflating: __MACOSX/data/train_recognition/images/._89874.png
#   inflating: data/train_recognition/images/107977.png
#   inflating: __MACOSX/data/train_recognition/images/._107977.png
#   inflating: data/train_recognition/images/128994.png
#   inflating: __MACOSX/data/train_recognition/images/._128994.png
#   inflating: data/train_recognition/images/25220.png
#   inflating: __MACOSX/data/train_recognition/images/._25220.png
#   inflating: data/train_recognition/images/141922.png
#   inflating: __MACOSX/data/train_recognition/images/._141922.png
#   inflating: data/train_recognition/images/14943.png
#   inflating: __MACOSX/data/train_recognition/images/._14943.png
#   inflating: data/train_recognition/images/52916.png
#   inflating: __MACOSX/data/train_recognition/images/._52916.png
#   inflating: data/train_recognition/images/136214.png
#   inflating: __MACOSX/data/train_recognition/images/._136214.png
#   inflating: data/train_recognition/images/63513.png
#   inflating: __MACOSX/data/train_recognition/images/._63513.png
#   inflating: data/train_recognition/images/2459_eng.png
#   inflating: data/train_recognition/images/139127.png
#   inflating: __MACOSX/data/train_recognition/images/._139127.png
#   inflating: data/train_recognition/images/80688.png
#   inflating: __MACOSX/data/train_recognition/images/._80688.png
#   inflating: data/train_recognition/images/25546.png
#   inflating: __MACOSX/data/train_recognition/images/._25546.png
#   inflating: data/train_recognition/images/121768.png
#   inflating: __MACOSX/data/train_recognition/images/._121768.png
#   inflating: data/train_recognition/images/22229.png
#   inflating: __MACOSX/data/train_recognition/images/._22229.png
#   inflating: data/train_recognition/images/126007.png
#   inflating: __MACOSX/data/train_recognition/images/._126007.png
#   inflating: data/train_recognition/images/12418_eng.png
#   inflating: data/train_recognition/images/15485.png
#   inflating: __MACOSX/data/train_recognition/images/._15485.png
#   inflating: data/train_recognition/images/35755.png
#   inflating: __MACOSX/data/train_recognition/images/._35755.png
#   inflating: data/train_recognition/images/140382.png
#   inflating: __MACOSX/data/train_recognition/images/._140382.png
#   inflating: data/train_recognition/images/6775_eng.png
#   inflating: data/train_recognition/images/24880.png
#   inflating: __MACOSX/data/train_recognition/images/._24880.png
#   inflating: data/train_recognition/images/73700.png
#   inflating: __MACOSX/data/train_recognition/images/._73700.png
#   inflating: data/train_recognition/images/129334.png
#   inflating: __MACOSX/data/train_recognition/images/._129334.png
#   inflating: data/train_recognition/images/65162.png
#   inflating: __MACOSX/data/train_recognition/images/._65162.png
#   inflating: data/train_recognition/images/127319.png
#   inflating: __MACOSX/data/train_recognition/images/._127319.png
#   inflating: data/train_recognition/images/13112_eng.png
#   inflating: data/train_recognition/images/23137.png
#   inflating: __MACOSX/data/train_recognition/images/._23137.png
#   inflating: data/train_recognition/images/91785.png
#   inflating: __MACOSX/data/train_recognition/images/._91785.png
#   inflating: data/train_recognition/images/80850.png
#   inflating: __MACOSX/data/train_recognition/images/._80850.png
#   inflating: data/train_recognition/images/130665.png
#   inflating: __MACOSX/data/train_recognition/images/._130665.png
#   inflating: data/train_recognition/images/33324.png
#   inflating: __MACOSX/data/train_recognition/images/._33324.png
#   inflating: data/train_recognition/images/75371.png
#   inflating: __MACOSX/data/train_recognition/images/._75371.png
#   inflating: data/train_recognition/images/9486_eng.png
#   inflating: data/train_recognition/images/111873.png
#   inflating: __MACOSX/data/train_recognition/images/._111873.png
#   inflating: data/train_recognition/images/120476.png
#   inflating: __MACOSX/data/train_recognition/images/._120476.png
#   inflating: data/train_recognition/images/24658.png
#   inflating: __MACOSX/data/train_recognition/images/._24658.png
#   inflating: data/train_recognition/images/81596.png
#   inflating: __MACOSX/data/train_recognition/images/._81596.png
#   inflating: data/train_recognition/images/138239.png
#   inflating: __MACOSX/data/train_recognition/images/._138239.png
#   inflating: data/train_recognition/images/3153_eng.png
#   inflating: data/train_recognition/images/105806.png
#   inflating: __MACOSX/data/train_recognition/images/._105806.png
#   inflating: data/train_recognition/images/61304.png
#   inflating: __MACOSX/data/train_recognition/images/._61304.png
#   inflating: data/train_recognition/images/8815_eng.png
#   inflating: data/train_recognition/images/143853.png
#   inflating: __MACOSX/data/train_recognition/images/._143853.png
#   inflating: data/train_recognition/images/27351.png
#   inflating: __MACOSX/data/train_recognition/images/._27351.png
#   inflating: data/train_recognition/images/1733_eng.png
#   inflating: data/train_recognition/images/28062.png
#   inflating: __MACOSX/data/train_recognition/images/._28062.png
#   inflating: data/train_recognition/images/76678.png
#   inflating: __MACOSX/data/train_recognition/images/._76678.png
#   inflating: data/train_recognition/images/134403.png
#   inflating: __MACOSX/data/train_recognition/images/._134403.png
#   inflating: data/train_recognition/images/69758.png
#   inflating: __MACOSX/data/train_recognition/images/._69758.png
#   inflating: data/train_recognition/images/11772_eng.png
#   inflating: data/train_recognition/images/37142.png
#   inflating: __MACOSX/data/train_recognition/images/._37142.png
#   inflating: data/train_recognition/images/142595.png
#   inflating: __MACOSX/data/train_recognition/images/._142595.png
#   inflating: data/train_recognition/images/71117.png
#   inflating: __MACOSX/data/train_recognition/images/._71117.png
#   inflating: data/train_recognition/images/94825.png
#   inflating: __MACOSX/data/train_recognition/images/._94825.png
#   inflating: data/train_recognition/images/124610.png
#   inflating: __MACOSX/data/train_recognition/images/._124610.png
#   inflating: data/train_recognition/images/49488.png
#   inflating: __MACOSX/data/train_recognition/images/._49488.png
#   inflating: data/train_recognition/images/38271.png
#   inflating: __MACOSX/data/train_recognition/images/._38271.png
#   inflating: data/train_recognition/images/17292.png
#   inflating: __MACOSX/data/train_recognition/images/._17292.png
#   inflating: data/train_recognition/images/70209.png
#   inflating: __MACOSX/data/train_recognition/images/._70209.png
#   inflating: data/train_recognition/images/10278_eng.png
#   inflating: data/train_recognition/images/93192.png
#   inflating: __MACOSX/data/train_recognition/images/._93192.png
#   inflating: data/train_recognition/images/132072.png
#   inflating: __MACOSX/data/train_recognition/images/._132072.png
#   inflating: data/train_recognition/images/68446.png
#   inflating: __MACOSX/data/train_recognition/images/._68446.png
#   inflating: data/train_recognition/images/59843.png
#   inflating: __MACOSX/data/train_recognition/images/._59843.png
#   inflating: data/train_recognition/images/67775.png
#   inflating: __MACOSX/data/train_recognition/images/._67775.png
#   inflating: data/train_recognition/images/48796.png
#   inflating: __MACOSX/data/train_recognition/images/._48796.png
#   inflating: data/train_recognition/images/4115_eng.png
#   inflating: data/train_recognition/images/21720.png
#   inflating: __MACOSX/data/train_recognition/images/._21720.png
#   inflating: data/train_recognition/images/122261.png
#   inflating: __MACOSX/data/train_recognition/images/._122261.png
#   inflating: data/train_recognition/images/78655.png
#   inflating: __MACOSX/data/train_recognition/images/._78655.png
#   inflating: data/train_recognition/images/83381.png
#   inflating: __MACOSX/data/train_recognition/images/._83381.png
#   inflating: data/train_recognition/images/46963.png
#   inflating: __MACOSX/data/train_recognition/images/._46963.png
#   inflating: data/train_recognition/images/69980.png
#   inflating: __MACOSX/data/train_recognition/images/._69980.png
#   inflating: data/train_recognition/images/14154_eng.png
#   inflating: data/train_recognition/images/31533.png
#   inflating: __MACOSX/data/train_recognition/images/._31533.png
#   inflating: data/train_recognition/images/85928.png
#   inflating: __MACOSX/data/train_recognition/images/._85928.png
#   inflating: data/train_recognition/images/77566.png
#   inflating: __MACOSX/data/train_recognition/images/._77566.png
#   inflating: data/train_recognition/images/58585.png
#   inflating: __MACOSX/data/train_recognition/images/._58585.png
#   inflating: data/train_recognition/images/113123.png
#   inflating: __MACOSX/data/train_recognition/images/._113123.png
#   inflating: data/train_recognition/images/49517.png
#   inflating: __MACOSX/data/train_recognition/images/._49517.png
#   inflating: data/train_recognition/images/8086_eng.png
#   inflating: data/train_recognition/images/51358.png
#   inflating: __MACOSX/data/train_recognition/images/._51358.png
#   inflating: data/train_recognition/images/71088.png
#   inflating: __MACOSX/data/train_recognition/images/._71088.png
#   inflating: data/train_recognition/images/46624.png
#   inflating: __MACOSX/data/train_recognition/images/._46624.png
#   inflating: data/train_recognition/images/92313.png
#   inflating: __MACOSX/data/train_recognition/images/._92313.png
#   inflating: data/train_recognition/images/78912.png
#   inflating: __MACOSX/data/train_recognition/images/._78912.png
#   inflating: data/train_recognition/images/2553_eng.png
#   inflating: data/train_recognition/images/21867.png
#   inflating: __MACOSX/data/train_recognition/images/._21867.png
#   inflating: data/train_recognition/images/2125.png
#   inflating: __MACOSX/data/train_recognition/images/._2125.png
#   inflating: data/train_recognition/images/145365.png
#   inflating: __MACOSX/data/train_recognition/images/._145365.png
#   inflating: data/train_recognition/images/67832.png
#   inflating: __MACOSX/data/train_recognition/images/._67832.png
#   inflating: data/train_recognition/images/103330.png
#   inflating: __MACOSX/data/train_recognition/images/._103330.png
#   inflating: data/train_recognition/images/12512_eng.png
#   inflating: data/train_recognition/images/59704.png
#   inflating: __MACOSX/data/train_recognition/images/._59704.png
#   inflating: data/train_recognition/images/82100.png
#   inflating: __MACOSX/data/train_recognition/images/._82100.png
#   inflating: data/train_recognition/images/56437.png
#   inflating: __MACOSX/data/train_recognition/images/._56437.png
#   inflating: data/train_recognition/images/105999.png
#   inflating: __MACOSX/data/train_recognition/images/._105999.png
#   inflating: data/train_recognition/images/10462.png
#   inflating: __MACOSX/data/train_recognition/images/._10462.png
#   inflating: data/train_recognition/images/13018_eng.png
#   inflating: data/train_recognition/images/135682.png
#   inflating: __MACOSX/data/train_recognition/images/._135682.png
#   inflating: data/train_recognition/images/40255.png
#   inflating: __MACOSX/data/train_recognition/images/._40255.png
#   inflating: data/train_recognition/images/124957.png
#   inflating: __MACOSX/data/train_recognition/images/._124957.png
#   inflating: data/train_recognition/images/94762.png
#   inflating: __MACOSX/data/train_recognition/images/._94762.png
#   inflating: data/train_recognition/images/115552.png
#   inflating: __MACOSX/data/train_recognition/images/._115552.png
#   inflating: data/train_recognition/images/60185.png
#   inflating: __MACOSX/data/train_recognition/images/._60185.png
#   inflating: data/train_recognition/images/4986_eng.png
#   inflating: data/train_recognition/images/7375_eng.png
#   inflating: data/train_recognition/images/57729.png
#   inflating: __MACOSX/data/train_recognition/images/._57729.png
#   inflating: data/train_recognition/images/5892.png
#   inflating: __MACOSX/data/train_recognition/images/._5892.png
#   inflating: data/train_recognition/images/84571.png
#   inflating: __MACOSX/data/train_recognition/images/._84571.png
#   inflating: data/train_recognition/images/125491.png
#   inflating: __MACOSX/data/train_recognition/images/._125491.png
#   inflating: data/train_recognition/images/50046.png
#   inflating: __MACOSX/data/train_recognition/images/._50046.png
#   inflating: data/train_recognition/images/48609.png
#   inflating: __MACOSX/data/train_recognition/images/._48609.png
#   inflating: data/train_recognition/images/16013.png
#   inflating: __MACOSX/data/train_recognition/images/._16013.png
#   inflating: data/train_recognition/images/19320.png
#   inflating: __MACOSX/data/train_recognition/images/._19320.png
#   inflating: data/train_recognition/images/3059_eng.png
#   inflating: data/train_recognition/images/143714.png
#   inflating: __MACOSX/data/train_recognition/images/._143714.png
#   inflating: data/train_recognition/images/4554.png
#   inflating: __MACOSX/data/train_recognition/images/._4554.png
#   inflating: data/train_recognition/images/114894.png
#   inflating: __MACOSX/data/train_recognition/images/._114894.png
#   inflating: data/train_recognition/images/105741.png
#   inflating: __MACOSX/data/train_recognition/images/._105741.png
#   inflating: data/train_recognition/images/70396.png
#   inflating: __MACOSX/data/train_recognition/images/._70396.png
#   inflating: data/train_recognition/images/106248.png
#   inflating: __MACOSX/data/train_recognition/images/._106248.png
#   inflating: data/train_recognition/images/44033.png
#   inflating: __MACOSX/data/train_recognition/images/._44033.png
#   inflating: data/train_recognition/images/90504.png
#   inflating: __MACOSX/data/train_recognition/images/._90504.png
#   inflating: data/train_recognition/images/111734.png
#   inflating: __MACOSX/data/train_recognition/images/._111734.png
#   inflating: data/train_recognition/images/1639_eng.png
#   inflating: data/train_recognition/images/126198.png
#   inflating: __MACOSX/data/train_recognition/images/._126198.png
#   inflating: data/train_recognition/images/87078.png
#   inflating: __MACOSX/data/train_recognition/images/._87078.png
#   inflating: data/train_recognition/images/130922.png
#   inflating: __MACOSX/data/train_recognition/images/._130922.png
#   inflating: data/train_recognition/images/80717.png
#   inflating: __MACOSX/data/train_recognition/images/._80717.png
#   inflating: data/train_recognition/images/54220.png
#   inflating: __MACOSX/data/train_recognition/images/._54220.png
#   inflating: data/train_recognition/images/11678_eng.png
#   inflating: data/train_recognition/images/98158.png
#   inflating: __MACOSX/data/train_recognition/images/._98158.png
#   inflating: data/train_recognition/images/12275.png
#   inflating: __MACOSX/data/train_recognition/images/._12275.png
#   inflating: data/train_recognition/images/52889.png
#   inflating: __MACOSX/data/train_recognition/images/._52889.png
#   inflating: data/train_recognition/images/119368.png
#   inflating: __MACOSX/data/train_recognition/images/._119368.png
#   inflating: data/train_recognition/images/5515_eng.png
#   inflating: data/train_recognition/images/101527.png
#   inflating: __MACOSX/data/train_recognition/images/._101527.png
#   inflating: data/train_recognition/images/117345.png
#   inflating: __MACOSX/data/train_recognition/images/._117345.png
#   inflating: data/train_recognition/images/62792.png
#   inflating: __MACOSX/data/train_recognition/images/._62792.png
#   inflating: data/train_recognition/images/13981_eng.png
#   inflating: data/train_recognition/images/10372_eng.png
#   inflating: data/train_recognition/images/73847.png
#   inflating: __MACOSX/data/train_recognition/images/._73847.png
#   inflating: data/train_recognition/images/99246.png
#   inflating: __MACOSX/data/train_recognition/images/._99246.png
#   inflating: data/train_recognition/images/81409.png
#   inflating: __MACOSX/data/train_recognition/images/._81409.png
#   inflating: data/train_recognition/images/35812.png
#   inflating: __MACOSX/data/train_recognition/images/._35812.png
#   inflating: data/train_recognition/images/100639.png
#   inflating: __MACOSX/data/train_recognition/images/._100639.png
#   inflating: data/train_recognition/images/137095.png
#   inflating: __MACOSX/data/train_recognition/images/._137095.png
#   inflating: data/train_recognition/images/42442.png
#   inflating: __MACOSX/data/train_recognition/images/._42442.png
#   inflating: data/train_recognition/images/118076.png
#   inflating: __MACOSX/data/train_recognition/images/._118076.png
#   inflating: data/train_recognition/images/96175.png
#   inflating: __MACOSX/data/train_recognition/images/._96175.png
#   inflating: data/train_recognition/images/141103.png
#   inflating: __MACOSX/data/train_recognition/images/._141103.png
#   inflating: data/train_recognition/images/6343.png
#   inflating: __MACOSX/data/train_recognition/images/._6343.png
#   inflating: data/train_recognition/images/89055.png
#   inflating: __MACOSX/data/train_recognition/images/._89055.png
#   inflating: data/train_recognition/images/107156.png
#   inflating: __MACOSX/data/train_recognition/images/._107156.png
#   inflating: data/train_recognition/images/72581.png
#   inflating: __MACOSX/data/train_recognition/images/._72581.png
#   inflating: data/train_recognition/images/43984.png
#   inflating: __MACOSX/data/train_recognition/images/._43984.png
#   inflating: data/train_recognition/images/86366.png
#   inflating: __MACOSX/data/train_recognition/images/._86366.png
#   inflating: data/train_recognition/images/127286.png
#   inflating: __MACOSX/data/train_recognition/images/._127286.png
#   inflating: data/train_recognition/images/52651.png
#   inflating: __MACOSX/data/train_recognition/images/._52651.png
#   inflating: data/train_recognition/images/108265.png
#   inflating: __MACOSX/data/train_recognition/images/._108265.png
#   inflating: data/train_recognition/images/9070.png
#   inflating: __MACOSX/data/train_recognition/images/._9070.png
#   inflating: data/train_recognition/images/14604.png
#   inflating: __MACOSX/data/train_recognition/images/._14604.png
#   inflating: data/train_recognition/images/141665.png
#   inflating: __MACOSX/data/train_recognition/images/._141665.png
#   inflating: data/train_recognition/images/6425.png
#   inflating: __MACOSX/data/train_recognition/images/._6425.png
#   inflating: data/train_recognition/images/107630.png
#   inflating: __MACOSX/data/train_recognition/images/._107630.png
#   inflating: data/train_recognition/images/46.png
#   inflating: __MACOSX/data/train_recognition/images/._46.png
#   inflating: data/train_recognition/images/89733.png
#   inflating: __MACOSX/data/train_recognition/images/._89733.png
#   inflating: data/train_recognition/images/139906.png
#   inflating: __MACOSX/data/train_recognition/images/._139906.png
#   inflating: data/train_recognition/images/52137.png
#   inflating: __MACOSX/data/train_recognition/images/._52137.png
#   inflating: data/train_recognition/images/108503.png
#   inflating: __MACOSX/data/train_recognition/images/._108503.png
#   inflating: data/train_recognition/images/86400.png
#   inflating: __MACOSX/data/train_recognition/images/._86400.png
#   inflating: data/train_recognition/images/9716.png
#   inflating: __MACOSX/data/train_recognition/images/._9716.png
#   inflating: data/train_recognition/images/14162.png
#   inflating: __MACOSX/data/train_recognition/images/._14162.png
#   inflating: data/train_recognition/images/6707_eng.png
#   inflating: data/train_recognition/images/99520.png
#   inflating: __MACOSX/data/train_recognition/images/._99520.png
#   inflating: data/train_recognition/images/117423.png
#   inflating: __MACOSX/data/train_recognition/images/._117423.png
#   inflating: data/train_recognition/images/55658.png
#   inflating: __MACOSX/data/train_recognition/images/._55658.png
#   inflating: data/train_recognition/images/75588.png
#   inflating: __MACOSX/data/train_recognition/images/._75588.png
#   inflating: data/train_recognition/images/96613.png
#   inflating: __MACOSX/data/train_recognition/images/._96613.png
#   inflating: data/train_recognition/images/126826.png
#   inflating: __MACOSX/data/train_recognition/images/._126826.png
#   inflating: data/train_recognition/images/42324.png
#   inflating: __MACOSX/data/train_recognition/images/._42324.png
#   inflating: data/train_recognition/images/118710.png
#   inflating: __MACOSX/data/train_recognition/images/._118710.png
#   inflating: data/train_recognition/images/121191.png
#   inflating: __MACOSX/data/train_recognition/images/._121191.png
#   inflating: data/train_recognition/images/54546.png
#   inflating: __MACOSX/data/train_recognition/images/._54546.png
#   inflating: data/train_recognition/images/80071.png
#   inflating: __MACOSX/data/train_recognition/images/._80071.png
#   inflating: data/train_recognition/images/12513.png
#   inflating: __MACOSX/data/train_recognition/images/._12513.png
#   inflating: data/train_recognition/images/147214.png
#   inflating: __MACOSX/data/train_recognition/images/._147214.png
#   inflating: data/train_recognition/images/3121_eng.png
#   inflating: data/train_recognition/images/23916.png
#   inflating: __MACOSX/data/train_recognition/images/._23916.png
#   inflating: data/train_recognition/images/101241.png
#   inflating: __MACOSX/data/train_recognition/images/._101241.png
#   inflating: data/train_recognition/images/74696.png
#   inflating: __MACOSX/data/train_recognition/images/._74696.png
#   inflating: data/train_recognition/images/65943.png
#   inflating: __MACOSX/data/train_recognition/images/._65943.png
#   inflating: data/train_recognition/images/13160_eng.png
#   inflating: data/train_recognition/images/90262.png
#   inflating: __MACOSX/data/train_recognition/images/._90262.png
#   inflating: data/train_recognition/images/55880.png
#   inflating: __MACOSX/data/train_recognition/images/._55880.png
#   inflating: data/train_recognition/images/131382.png
#   inflating: __MACOSX/data/train_recognition/images/._131382.png
#   inflating: data/train_recognition/images/44755.png
#   inflating: __MACOSX/data/train_recognition/images/._44755.png
#   inflating: data/train_recognition/images/111052.png
#   inflating: __MACOSX/data/train_recognition/images/._111052.png
#   inflating: data/train_recognition/images/64485.png
#   inflating: __MACOSX/data/train_recognition/images/._64485.png
#   inflating: data/train_recognition/images/8408.png
#   inflating: __MACOSX/data/train_recognition/images/._8408.png
#   inflating: data/train_recognition/images/53229.png
#   inflating: __MACOSX/data/train_recognition/images/._53229.png
#   inflating: data/train_recognition/images/806.png
#   inflating: __MACOSX/data/train_recognition/images/._806.png
#   inflating: data/train_recognition/images/50720.png
#   inflating: __MACOSX/data/train_recognition/images/._50720.png
#   inflating: data/train_recognition/images/84217.png
#   inflating: __MACOSX/data/train_recognition/images/._84217.png
#   inflating: data/train_recognition/images/39796.png
#   inflating: __MACOSX/data/train_recognition/images/._39796.png
#   inflating: data/train_recognition/images/16775.png
#   inflating: __MACOSX/data/train_recognition/images/._16775.png
#   inflating: data/train_recognition/images/11700_eng.png
#   inflating: data/train_recognition/images/28843.png
#   inflating: __MACOSX/data/train_recognition/images/._28843.png
#   inflating: data/train_recognition/images/19446.png
#   inflating: __MACOSX/data/train_recognition/images/._19446.png
#   inflating: data/train_recognition/images/143072.png
#   inflating: __MACOSX/data/train_recognition/images/._143072.png
#   inflating: data/train_recognition/images/4232.png
#   inflating: __MACOSX/data/train_recognition/images/._4232.png
#   inflating: data/train_recognition/images/105027.png
#   inflating: __MACOSX/data/train_recognition/images/._105027.png
#   inflating: data/train_recognition/images/29585.png
#   inflating: __MACOSX/data/train_recognition/images/._29585.png
#   inflating: data/train_recognition/images/102748.png
#   inflating: __MACOSX/data/train_recognition/images/._102748.png
#   inflating: data/train_recognition/images/94004.png
#   inflating: __MACOSX/data/train_recognition/images/._94004.png
#   inflating: data/train_recognition/images/40533.png
#   inflating: __MACOSX/data/train_recognition/images/._40533.png
#   inflating: data/train_recognition/images/8867_eng.png
#   inflating: data/train_recognition/images/71936.png
#   inflating: __MACOSX/data/train_recognition/images/._71936.png
#   inflating: data/train_recognition/images/115234.png
#   inflating: __MACOSX/data/train_recognition/images/._115234.png
#   inflating: data/train_recognition/images/291_eng.png
#   inflating: data/train_recognition/images/18980.png
#   inflating: __MACOSX/data/train_recognition/images/._18980.png
#   inflating: data/train_recognition/images/83578.png
#   inflating: __MACOSX/data/train_recognition/images/._83578.png
#   inflating: data/train_recognition/images/1741_eng.png
#   inflating: data/train_recognition/images/37963.png
#   inflating: __MACOSX/data/train_recognition/images/._37963.png
#   inflating: data/train_recognition/images/122498.png
#   inflating: __MACOSX/data/train_recognition/images/._122498.png
#   inflating: data/train_recognition/images/2643.png
#   inflating: __MACOSX/data/train_recognition/images/._2643.png
#   inflating: data/train_recognition/images/14126_eng.png
#   inflating: data/train_recognition/images/145403.png
#   inflating: __MACOSX/data/train_recognition/images/._145403.png
#   inflating: data/train_recognition/images/103456.png
#   inflating: __MACOSX/data/train_recognition/images/._103456.png
#   inflating: data/train_recognition/images/76081.png
#   inflating: __MACOSX/data/train_recognition/images/._76081.png
#   inflating: data/train_recognition/images/59062.png
#   inflating: __MACOSX/data/train_recognition/images/._59062.png
#   inflating: data/train_recognition/images/123786.png
#   inflating: __MACOSX/data/train_recognition/images/._123786.png
#   inflating: data/train_recognition/images/56351.png
#   inflating: __MACOSX/data/train_recognition/images/._56351.png
#   inflating: data/train_recognition/images/82666.png
#   inflating: __MACOSX/data/train_recognition/images/._82666.png
#   inflating: data/train_recognition/images/132853.png
#   inflating: __MACOSX/data/train_recognition/images/._132853.png
#   inflating: data/train_recognition/images/10304.png
#   inflating: __MACOSX/data/train_recognition/images/._10304.png
#   inflating: data/train_recognition/images/102990.png
#   inflating: __MACOSX/data/train_recognition/images/._102990.png
#   inflating: data/train_recognition/images/113645.png
#   inflating: __MACOSX/data/train_recognition/images/._113645.png
#   inflating: data/train_recognition/images/66292.png
#   inflating: __MACOSX/data/train_recognition/images/._66292.png
#   inflating: data/train_recognition/images/49271.png
#   inflating: __MACOSX/data/train_recognition/images/._49271.png
#   inflating: data/train_recognition/images/38488.png
#   inflating: __MACOSX/data/train_recognition/images/._38488.png
#   inflating: data/train_recognition/images/85109.png
#   inflating: __MACOSX/data/train_recognition/images/._85109.png
#   inflating: data/train_recognition/images/4167_eng.png
#   inflating: data/train_recognition/images/104339.png
#   inflating: __MACOSX/data/train_recognition/images/._104339.png
#   inflating: data/train_recognition/images/92475.png
#   inflating: __MACOSX/data/train_recognition/images/._92475.png
#   inflating: data/train_recognition/images/133595.png
#   inflating: __MACOSX/data/train_recognition/images/._133595.png
#   inflating: data/train_recognition/images/46142.png
#   inflating: __MACOSX/data/train_recognition/images/._46142.png
#   inflating: data/train_recognition/images/18758.png
#   inflating: __MACOSX/data/train_recognition/images/._18758.png
#   inflating: data/train_recognition/images/28857.png
#   inflating: __MACOSX/data/train_recognition/images/._28857.png
#   inflating: data/train_recognition/images/67198.png
#   inflating: __MACOSX/data/train_recognition/images/._67198.png
#   inflating: data/train_recognition/images/16761.png
#   inflating: __MACOSX/data/train_recognition/images/._16761.png
#   inflating: data/train_recognition/images/39782.png
#   inflating: __MACOSX/data/train_recognition/images/._39782.png
#   inflating: data/train_recognition/images/84203.png
#   inflating: __MACOSX/data/train_recognition/images/._84203.png
#   inflating: data/train_recognition/images/11668_eng.png
#   inflating: data/train_recognition/images/50734.png
#   inflating: __MACOSX/data/train_recognition/images/._50734.png
#   inflating: data/train_recognition/images/105033.png
#   inflating: __MACOSX/data/train_recognition/images/._105033.png
#   inflating: data/train_recognition/images/4226.png
#   inflating: __MACOSX/data/train_recognition/images/._4226.png
#   inflating: data/train_recognition/images/47248.png
#   inflating: __MACOSX/data/train_recognition/images/._47248.png
#   inflating: data/train_recognition/images/143066.png
#   inflating: __MACOSX/data/train_recognition/images/._143066.png
#   inflating: data/train_recognition/images/5505_eng.png
#   inflating: data/train_recognition/images/19452.png
#   inflating: __MACOSX/data/train_recognition/images/._19452.png
#   inflating: data/train_recognition/images/3549.png
#   inflating: __MACOSX/data/train_recognition/images/._3549.png
#   inflating: data/train_recognition/images/40527.png
#   inflating: __MACOSX/data/train_recognition/images/._40527.png
#   inflating: data/train_recognition/images/144709.png
#   inflating: __MACOSX/data/train_recognition/images/._144709.png
#   inflating: data/train_recognition/images/94010.png
#   inflating: __MACOSX/data/train_recognition/images/._94010.png
#   inflating: data/train_recognition/images/29591.png
#   inflating: __MACOSX/data/train_recognition/images/._29591.png
#   inflating: data/train_recognition/images/58368.png
#   inflating: __MACOSX/data/train_recognition/images/._58368.png
#   inflating: data/train_recognition/images/113889.png
#   inflating: __MACOSX/data/train_recognition/images/._113889.png
#   inflating: data/train_recognition/images/37977.png
#   inflating: __MACOSX/data/train_recognition/images/._37977.png
#   inflating: data/train_recognition/images/18994.png
#   inflating: __MACOSX/data/train_recognition/images/._18994.png
#   inflating: data/train_recognition/images/115220.png
#   inflating: __MACOSX/data/train_recognition/images/._115220.png
#   inflating: data/train_recognition/images/1629_eng.png
#   inflating: data/train_recognition/images/71922.png
#   inflating: __MACOSX/data/train_recognition/images/._71922.png
#   inflating: data/train_recognition/images/59076.png
#   inflating: __MACOSX/data/train_recognition/images/._59076.png
#   inflating: data/train_recognition/images/103442.png
#   inflating: __MACOSX/data/train_recognition/images/._103442.png
#   inflating: data/train_recognition/images/76095.png
#   inflating: __MACOSX/data/train_recognition/images/._76095.png
#   inflating: data/train_recognition/images/145417.png
#   inflating: __MACOSX/data/train_recognition/images/._145417.png
#   inflating: data/train_recognition/images/2657.png
#   inflating: __MACOSX/data/train_recognition/images/._2657.png
#   inflating: data/train_recognition/images/41639.png
#   inflating: __MACOSX/data/train_recognition/images/._41639.png
#   inflating: data/train_recognition/images/10310.png
#   inflating: __MACOSX/data/train_recognition/images/._10310.png
#   inflating: data/train_recognition/images/132847.png
#   inflating: __MACOSX/data/train_recognition/images/._132847.png
#   inflating: data/train_recognition/images/82672.png
#   inflating: __MACOSX/data/train_recognition/images/._82672.png
#   inflating: data/train_recognition/images/123792.png
#   inflating: __MACOSX/data/train_recognition/images/._123792.png
#   inflating: data/train_recognition/images/56345.png
#   inflating: __MACOSX/data/train_recognition/images/._56345.png
#   inflating: data/train_recognition/images/13991_eng.png
#   inflating: data/train_recognition/images/10362_eng.png
#   inflating: data/train_recognition/images/49265.png
#   inflating: __MACOSX/data/train_recognition/images/._49265.png
#   inflating: data/train_recognition/images/113651.png
#   inflating: __MACOSX/data/train_recognition/images/._113651.png
#   inflating: data/train_recognition/images/66286.png
#   inflating: __MACOSX/data/train_recognition/images/._66286.png
#   inflating: data/train_recognition/images/102984.png
#   inflating: __MACOSX/data/train_recognition/images/._102984.png
#   inflating: data/train_recognition/images/142378.png
#   inflating: __MACOSX/data/train_recognition/images/._142378.png
#   inflating: data/train_recognition/images/133581.png
#   inflating: __MACOSX/data/train_recognition/images/._133581.png
#   inflating: data/train_recognition/images/46156.png
#   inflating: __MACOSX/data/train_recognition/images/._46156.png
#   inflating: data/train_recognition/images/5138.png
#   inflating: __MACOSX/data/train_recognition/images/._5138.png
#   inflating: data/train_recognition/images/92461.png
#   inflating: __MACOSX/data/train_recognition/images/._92461.png
#   inflating: data/train_recognition/images/139912.png
#   inflating: __MACOSX/data/train_recognition/images/._139912.png
#   inflating: data/train_recognition/images/89727.png
#   inflating: __MACOSX/data/train_recognition/images/._89727.png
#   inflating: data/train_recognition/images/52.png
#   inflating: __MACOSX/data/train_recognition/images/._52.png
#   inflating: data/train_recognition/images/107624.png
#   inflating: __MACOSX/data/train_recognition/images/._107624.png
#   inflating: data/train_recognition/images/91168.png
#   inflating: __MACOSX/data/train_recognition/images/._91168.png
#   inflating: data/train_recognition/images/12502_eng.png
#   inflating: data/train_recognition/images/6431.png
#   inflating: __MACOSX/data/train_recognition/images/._6431.png
#   inflating: data/train_recognition/images/130088.png
#   inflating: __MACOSX/data/train_recognition/images/._130088.png
#   inflating: data/train_recognition/images/141671.png
#   inflating: __MACOSX/data/train_recognition/images/._141671.png
#   inflating: data/train_recognition/images/110358.png
#   inflating: __MACOSX/data/train_recognition/images/._110358.png
#   inflating: data/train_recognition/images/14176.png
#   inflating: __MACOSX/data/train_recognition/images/._14176.png
#   inflating: data/train_recognition/images/9702.png
#   inflating: __MACOSX/data/train_recognition/images/._9702.png
#   inflating: data/train_recognition/images/86414.png
#   inflating: __MACOSX/data/train_recognition/images/._86414.png
#   inflating: data/train_recognition/images/108517.png
#   inflating: __MACOSX/data/train_recognition/images/._108517.png
#   inflating: data/train_recognition/images/52123.png
#   inflating: __MACOSX/data/train_recognition/images/._52123.png
#   inflating: data/train_recognition/images/44999.png
#   inflating: __MACOSX/data/train_recognition/images/._44999.png
#   inflating: data/train_recognition/images/117437.png
#   inflating: __MACOSX/data/train_recognition/images/._117437.png
#   inflating: data/train_recognition/images/13619.png
#   inflating: __MACOSX/data/train_recognition/images/._13619.png
#   inflating: data/train_recognition/images/99534.png
#   inflating: __MACOSX/data/train_recognition/images/._99534.png
#   inflating: data/train_recognition/images/8096_eng.png
#   inflating: data/train_recognition/images/118704.png
#   inflating: __MACOSX/data/train_recognition/images/._118704.png
#   inflating: data/train_recognition/images/42330.png
#   inflating: __MACOSX/data/train_recognition/images/._42330.png
#   inflating: data/train_recognition/images/126832.png
#   inflating: __MACOSX/data/train_recognition/images/._126832.png
#   inflating: data/train_recognition/images/96607.png
#   inflating: __MACOSX/data/train_recognition/images/._96607.png
#   inflating: data/train_recognition/images/2543_eng.png
#   inflating: data/train_recognition/images/12507.png
#   inflating: __MACOSX/data/train_recognition/images/._12507.png
#   inflating: data/train_recognition/images/116729.png
#   inflating: __MACOSX/data/train_recognition/images/._116729.png
#   inflating: data/train_recognition/images/80065.png
#   inflating: __MACOSX/data/train_recognition/images/._80065.png
#   inflating: data/train_recognition/images/121185.png
#   inflating: __MACOSX/data/train_recognition/images/._121185.png
#   inflating: data/train_recognition/images/54552.png
#   inflating: __MACOSX/data/train_recognition/images/._54552.png
#   inflating: data/train_recognition/images/3049_eng.png
#   inflating: data/train_recognition/images/65957.png
#   inflating: __MACOSX/data/train_recognition/images/._65957.png
#   inflating: data/train_recognition/images/101255.png
#   inflating: __MACOSX/data/train_recognition/images/._101255.png
#   inflating: data/train_recognition/images/74682.png
#   inflating: __MACOSX/data/train_recognition/images/._74682.png
#   inflating: data/train_recognition/images/23902.png
#   inflating: __MACOSX/data/train_recognition/images/._23902.png
#   inflating: data/train_recognition/images/97519.png
#   inflating: __MACOSX/data/train_recognition/images/._97519.png
#   inflating: data/train_recognition/images/147200.png
#   inflating: __MACOSX/data/train_recognition/images/._147200.png
#   inflating: data/train_recognition/images/13008_eng.png
#   inflating: data/train_recognition/images/131396.png
#   inflating: __MACOSX/data/train_recognition/images/._131396.png
#   inflating: data/train_recognition/images/44741.png
#   inflating: __MACOSX/data/train_recognition/images/._44741.png
#   inflating: data/train_recognition/images/55894.png
#   inflating: __MACOSX/data/train_recognition/images/._55894.png
#   inflating: data/train_recognition/images/90276.png
#   inflating: __MACOSX/data/train_recognition/images/._90276.png
#   inflating: data/train_recognition/images/88439.png
#   inflating: __MACOSX/data/train_recognition/images/._88439.png
#   inflating: data/train_recognition/images/812.png
#   inflating: __MACOSX/data/train_recognition/images/._812.png
#   inflating: data/train_recognition/images/4996_eng.png
#   inflating: data/train_recognition/images/109609.png
#   inflating: __MACOSX/data/train_recognition/images/._109609.png
#   inflating: data/train_recognition/images/7365_eng.png
#   inflating: data/train_recognition/images/15268.png
#   inflating: __MACOSX/data/train_recognition/images/._15268.png
#   inflating: data/train_recognition/images/111046.png
#   inflating: __MACOSX/data/train_recognition/images/._111046.png
#   inflating: data/train_recognition/images/64491.png
#   inflating: __MACOSX/data/train_recognition/images/._64491.png
#   inflating: data/train_recognition/images/90510.png
#   inflating: __MACOSX/data/train_recognition/images/._90510.png
#   inflating: data/train_recognition/images/140209.png
#   inflating: __MACOSX/data/train_recognition/images/._140209.png
#   inflating: data/train_recognition/images/44027.png
#   inflating: __MACOSX/data/train_recognition/images/._44027.png
#   inflating: data/train_recognition/images/7049.png
#   inflating: __MACOSX/data/train_recognition/images/._7049.png
#   inflating: data/train_recognition/images/8877_eng.png
#   inflating: data/train_recognition/images/281_eng.png
#   inflating: data/train_recognition/images/1751_eng.png
#   inflating: data/train_recognition/images/111720.png
#   inflating: __MACOSX/data/train_recognition/images/._111720.png
#   inflating: data/train_recognition/images/12261.png
#   inflating: __MACOSX/data/train_recognition/images/._12261.png
#   inflating: data/train_recognition/images/63498.png
#   inflating: __MACOSX/data/train_recognition/images/._63498.png
#   inflating: data/train_recognition/images/54234.png
#   inflating: __MACOSX/data/train_recognition/images/._54234.png
#   inflating: data/train_recognition/images/80703.png
#   inflating: __MACOSX/data/train_recognition/images/._80703.png
#   inflating: data/train_recognition/images/130936.png
#   inflating: __MACOSX/data/train_recognition/images/._130936.png
#   inflating: data/train_recognition/images/11710_eng.png
#   inflating: data/train_recognition/images/101533.png
#   inflating: __MACOSX/data/train_recognition/images/._101533.png
#   inflating: data/train_recognition/images/43748.png
#   inflating: __MACOSX/data/train_recognition/images/._43748.png
#   inflating: data/train_recognition/images/35806.png
#   inflating: __MACOSX/data/train_recognition/images/._35806.png
#   inflating: data/train_recognition/images/99252.png
#   inflating: __MACOSX/data/train_recognition/images/._99252.png
#   inflating: data/train_recognition/images/73853.png
#   inflating: __MACOSX/data/train_recognition/images/._73853.png
#   inflating: data/train_recognition/images/117351.png
#   inflating: __MACOSX/data/train_recognition/images/._117351.png
# ...
#   inflating: data/train_recognition/images/84940.png
#   inflating: __MACOSX/data/train_recognition/images/._84940.png
#   inflating: data/train_recognition/images/61072.png
#   inflating: __MACOSX/data/train_recognition/images/._61072.png
#   inflating: data/train_recognition/images/4965.png
#   inflating: __MACOSX/data/train_recognition/images/._4965.png
#   inflating: data/train_recognition/images/123209.png
#   inflating: __MACOSX/data/train_recognition/images/._123209.png
#   inflating: data/train_recognition/images/27027.png
#   inflating: __MACOSX/data/train_recognition/images/._27027.png
#   inflating: data/train_recognition/images/124566.png
#   inflating: __MACOSX/data/train_recognition/images/._124566.png
#   inflating: data/train_recognition/images/20748.png
#   inflating: __MACOSX/data/train_recognition/images/._20748.png
#   inflating: data/train_recognition/images/85486.png
#   inflating: __MACOSX/data/train_recognition/images/._85486.png
#   inflating: data/train_recognition/images/38107.png
#   inflating: __MACOSX/data/train_recognition/images/._38107.png
#   inflating: data/train_recognition/images/37234.png
#   inflating: __MACOSX/data/train_recognition/images/._37234.png
#   inflating: data/train_recognition/images/9370_eng.png
#   inflating: data/train_recognition/images/71261.png
#   inflating: __MACOSX/data/train_recognition/images/._71261.png
#   inflating: data/train_recognition/images/115963.png
#   inflating: __MACOSX/data/train_recognition/images/._115963.png
#   inflating: data/train_recognition/images/39219.png
#   inflating: __MACOSX/data/train_recognition/images/._39219.png
#   inflating: data/train_recognition/images/67403.png
#   inflating: __MACOSX/data/train_recognition/images/._67403.png
#   inflating: data/train_recognition/images/84798.png
#   inflating: __MACOSX/data/train_recognition/images/._84798.png
#   inflating: data/train_recognition/images/21456.png
#   inflating: __MACOSX/data/train_recognition/images/._21456.png
#   inflating: data/train_recognition/images/125678.png
#   inflating: __MACOSX/data/train_recognition/images/._125678.png
#   inflating: data/train_recognition/images/10853.png
#   inflating: __MACOSX/data/train_recognition/images/._10853.png
#   inflating: data/train_recognition/images/56806.png
#   inflating: __MACOSX/data/train_recognition/images/._56806.png
#   inflating: data/train_recognition/images/68730.png
#   inflating: __MACOSX/data/train_recognition/images/._68730.png
#   inflating: data/train_recognition/images/132304.png
#   inflating: __MACOSX/data/train_recognition/images/._132304.png
#   inflating: data/train_recognition/images/31645.png
#   inflating: __MACOSX/data/train_recognition/images/._31645.png
#   inflating: data/train_recognition/images/144292.png
#   inflating: __MACOSX/data/train_recognition/images/._144292.png
#   inflating: data/train_recognition/images/20990.png
#   inflating: __MACOSX/data/train_recognition/images/._20990.png
#   inflating: data/train_recognition/images/6083_eng.png
#   inflating: data/train_recognition/images/77610.png
#   inflating: __MACOSX/data/train_recognition/images/._77610.png
#   inflating: data/train_recognition/images/49926.png
#   inflating: __MACOSX/data/train_recognition/images/._49926.png
#   inflating: data/train_recognition/images/78523.png
#   inflating: __MACOSX/data/train_recognition/images/._78523.png
#   inflating: data/train_recognition/images/26339.png
#   inflating: __MACOSX/data/train_recognition/images/._26339.png
#   inflating: data/train_recognition/images/122117.png
#   inflating: __MACOSX/data/train_recognition/images/._122117.png
#   inflating: data/train_recognition/images/11595.png
#   inflating: __MACOSX/data/train_recognition/images/._11595.png
#   inflating: data/train_recognition/images/139251.png
#   inflating: __MACOSX/data/train_recognition/images/._139251.png
#   inflating: data/train_recognition/images/63665.png
#   inflating: __MACOSX/data/train_recognition/images/._63665.png
#   inflating: data/train_recognition/images/25630.png
#   inflating: __MACOSX/data/train_recognition/images/._25630.png
#   inflating: data/train_recognition/images/74319.png
#   inflating: __MACOSX/data/train_recognition/images/._74319.png
#   inflating: data/train_recognition/images/97082.png
#   inflating: __MACOSX/data/train_recognition/images/._97082.png
#   inflating: data/train_recognition/images/119181.png
#   inflating: __MACOSX/data/train_recognition/images/._119181.png
#   inflating: data/train_recognition/images/136162.png
#   inflating: __MACOSX/data/train_recognition/images/._136162.png
#   inflating: data/train_recognition/images/35423.png
#   inflating: __MACOSX/data/train_recognition/images/._35423.png
#   inflating: data/train_recognition/images/81838.png
#   inflating: __MACOSX/data/train_recognition/images/._81838.png
#   inflating: data/train_recognition/images/129042.png
#   inflating: __MACOSX/data/train_recognition/images/._129042.png
#   inflating: data/train_recognition/images/73476.png
#   inflating: __MACOSX/data/train_recognition/images/._73476.png
#   inflating: data/train_recognition/images/109392.png
#   inflating: __MACOSX/data/train_recognition/images/._109392.png
#   inflating: data/train_recognition/images/126371.png
#   inflating: __MACOSX/data/train_recognition/images/._126371.png
#   inflating: data/train_recognition/images/42873.png
#   inflating: __MACOSX/data/train_recognition/images/._42873.png
#   inflating: data/train_recognition/images/87291.png
#   inflating: __MACOSX/data/train_recognition/images/._87291.png
#   inflating: data/train_recognition/images/8187.png
#   inflating: __MACOSX/data/train_recognition/images/._8187.png
#   inflating: data/train_recognition/images/515_eng.png
#   inflating: data/train_recognition/images/72768.png
#   inflating: __MACOSX/data/train_recognition/images/._72768.png
#   inflating: data/train_recognition/images/130513.png
#   inflating: __MACOSX/data/train_recognition/images/._130513.png
#   inflating: data/train_recognition/images/101916.png
#   inflating: __MACOSX/data/train_recognition/images/._101916.png
#   inflating: data/train_recognition/images/9299.png
#   inflating: __MACOSX/data/train_recognition/images/._9299.png
#   inflating: data/train_recognition/images/65214.png
#   inflating: __MACOSX/data/train_recognition/images/._65214.png
#   inflating: data/train_recognition/images/23241.png
#   inflating: __MACOSX/data/train_recognition/images/._23241.png
#   inflating: data/train_recognition/images/120700.png
#   inflating: __MACOSX/data/train_recognition/images/._120700.png
#   inflating: data/train_recognition/images/90935.png
#   inflating: __MACOSX/data/train_recognition/images/._90935.png
#   inflating: data/train_recognition/images/13382.png
#   inflating: __MACOSX/data/train_recognition/images/._13382.png
#   inflating: data/train_recognition/images/33052.png
#   inflating: __MACOSX/data/train_recognition/images/._33052.png
#   inflating: data/train_recognition/images/146485.png
#   inflating: __MACOSX/data/train_recognition/images/._146485.png
#   inflating: data/train_recognition/images/11084_eng.png
#   inflating: data/train_recognition/images/351.png
#   inflating: __MACOSX/data/train_recognition/images/._351.png
#   inflating: data/train_recognition/images/75007.png
#   inflating: __MACOSX/data/train_recognition/images/._75007.png
#   inflating: data/train_recognition/images/81186.png
#   inflating: __MACOSX/data/train_recognition/images/._81186.png
#   inflating: data/train_recognition/images/24248.png
#   inflating: __MACOSX/data/train_recognition/images/._24248.png
#   inflating: data/train_recognition/images/120066.png
#   inflating: __MACOSX/data/train_recognition/images/._120066.png
#   inflating: data/train_recognition/images/138629.png
#   inflating: __MACOSX/data/train_recognition/images/._138629.png
#   inflating: data/train_recognition/images/437.png
#   inflating: __MACOSX/data/train_recognition/images/._437.png
#   inflating: data/train_recognition/images/33734.png
#   inflating: __MACOSX/data/train_recognition/images/._33734.png
#   inflating: data/train_recognition/images/8839.png
#   inflating: __MACOSX/data/train_recognition/images/._8839.png
#   inflating: data/train_recognition/images/9208_eng.png
#   inflating: data/train_recognition/images/75761.png
#   inflating: __MACOSX/data/train_recognition/images/._75761.png
#   inflating: data/train_recognition/images/12922.png
#   inflating: __MACOSX/data/train_recognition/images/._12922.png
#   inflating: data/train_recognition/images/130275.png
#   inflating: __MACOSX/data/train_recognition/images/._130275.png
#   inflating: data/train_recognition/images/91395.png
#   inflating: __MACOSX/data/train_recognition/images/._91395.png
#   inflating: data/train_recognition/images/54977.png
#   inflating: __MACOSX/data/train_recognition/images/._54977.png
#   inflating: data/train_recognition/images/65572.png
#   inflating: __MACOSX/data/train_recognition/images/._65572.png
#   inflating: data/train_recognition/images/23527.png
#   inflating: __MACOSX/data/train_recognition/images/._23527.png
#   inflating: data/train_recognition/images/127709.png
#   inflating: __MACOSX/data/train_recognition/images/._127709.png
#   inflating: data/train_recognition/images/35345.png
#   inflating: __MACOSX/data/train_recognition/images/._35345.png
#   inflating: data/train_recognition/images/140792.png
#   inflating: __MACOSX/data/train_recognition/images/._140792.png
#   inflating: data/train_recognition/images/117812.png
#   inflating: __MACOSX/data/train_recognition/images/._117812.png
#   inflating: data/train_recognition/images/99911.png
#   inflating: __MACOSX/data/train_recognition/images/._99911.png
#   inflating: data/train_recognition/images/129724.png
#   inflating: __MACOSX/data/train_recognition/images/._129724.png
#   inflating: data/train_recognition/images/73310.png
#   inflating: __MACOSX/data/train_recognition/images/._73310.png
#   inflating: data/train_recognition/images/11865_eng.png
#   inflating: data/train_recognition/images/126417.png
#   inflating: __MACOSX/data/train_recognition/images/._126417.png
#   inflating: data/train_recognition/images/22639.png
#   inflating: __MACOSX/data/train_recognition/images/._22639.png
#   inflating: data/train_recognition/images/12296_eng.png
#   inflating: data/train_recognition/images/15095.png
#   inflating: __MACOSX/data/train_recognition/images/._15095.png
#   inflating: data/train_recognition/images/139537.png
#   inflating: __MACOSX/data/train_recognition/images/._139537.png
#   inflating: data/train_recognition/images/63103.png
#   inflating: __MACOSX/data/train_recognition/images/._63103.png
#   inflating: data/train_recognition/images/1824_eng.png
#   inflating: data/train_recognition/images/121378.png
#   inflating: __MACOSX/data/train_recognition/images/._121378.png
#   inflating: data/train_recognition/images/25156.png
#   inflating: __MACOSX/data/train_recognition/images/._25156.png
#   inflating: data/train_recognition/images/6814.png
#   inflating: __MACOSX/data/train_recognition/images/._6814.png
#   inflating: data/train_recognition/images/80298.png
#   inflating: __MACOSX/data/train_recognition/images/._80298.png
#   inflating: data/train_recognition/images/8702_eng.png
#   inflating: data/train_recognition/images/86831.png
#   inflating: __MACOSX/data/train_recognition/images/._86831.png
#   inflating: data/train_recognition/images/136604.png
#   inflating: __MACOSX/data/train_recognition/images/._136604.png
#   inflating: data/train_recognition/images/108932.png
#   inflating: __MACOSX/data/train_recognition/images/._108932.png
#   inflating: data/train_recognition/images/31123.png
#   inflating: __MACOSX/data/train_recognition/images/._31123.png
#   inflating: data/train_recognition/images/58195.png
#   inflating: __MACOSX/data/train_recognition/images/._58195.png
#   inflating: data/train_recognition/images/77176.png
#   inflating: __MACOSX/data/train_recognition/images/._77176.png
#   inflating: data/train_recognition/images/83791.png
#   inflating: __MACOSX/data/train_recognition/images/._83791.png
#   inflating: data/train_recognition/images/78245.png
#   inflating: __MACOSX/data/train_recognition/images/._78245.png
#   inflating: data/train_recognition/images/92844.png
#   inflating: __MACOSX/data/train_recognition/images/._92844.png
#   inflating: data/train_recognition/images/122671.png
#   inflating: __MACOSX/data/train_recognition/images/._122671.png
#   inflating: data/train_recognition/images/48386.png
#   inflating: __MACOSX/data/train_recognition/images/._48386.png
#   inflating: data/train_recognition/images/67365.png
#   inflating: __MACOSX/data/train_recognition/images/._67365.png
#   inflating: data/train_recognition/images/103867.png
#   inflating: __MACOSX/data/train_recognition/images/._103867.png
#   inflating: data/train_recognition/images/21330.png
#   inflating: __MACOSX/data/train_recognition/images/._21330.png
#   inflating: data/train_recognition/images/145832.png
#   inflating: __MACOSX/data/train_recognition/images/._145832.png
#   inflating: data/train_recognition/images/70619.png
#   inflating: __MACOSX/data/train_recognition/images/._70619.png
#   inflating: data/train_recognition/images/68056.png
#   inflating: __MACOSX/data/train_recognition/images/._68056.png
#   inflating: data/train_recognition/images/132462.png
#   inflating: __MACOSX/data/train_recognition/images/._132462.png
#   inflating: data/train_recognition/images/93582.png
#   inflating: __MACOSX/data/train_recognition/images/._93582.png
#   inflating: data/train_recognition/images/27999.png
#   inflating: __MACOSX/data/train_recognition/images/._27999.png
#   inflating: data/train_recognition/images/6862_eng.png
#   inflating: data/train_recognition/images/5291_eng.png
#   inflating: data/train_recognition/images/40902.png
#   inflating: __MACOSX/data/train_recognition/images/._40902.png
#   inflating: data/train_recognition/images/124200.png
#   inflating: __MACOSX/data/train_recognition/images/._124200.png
#   inflating: data/train_recognition/images/17682.png
#   inflating: __MACOSX/data/train_recognition/images/._17682.png
#   inflating: data/train_recognition/images/38661.png
#   inflating: __MACOSX/data/train_recognition/images/._38661.png
#   inflating: data/train_recognition/images/49098.png
#   inflating: __MACOSX/data/train_recognition/images/._49098.png
#   inflating: data/train_recognition/images/37552.png
#   inflating: __MACOSX/data/train_recognition/images/._37552.png
#   inflating: data/train_recognition/images/142185.png
#   inflating: __MACOSX/data/train_recognition/images/._142185.png
#   inflating: data/train_recognition/images/83949.png
#   inflating: __MACOSX/data/train_recognition/images/._83949.png
#   inflating: data/train_recognition/images/69348.png
#   inflating: __MACOSX/data/train_recognition/images/._69348.png
#   inflating: data/train_recognition/images/71507.png
#   inflating: __MACOSX/data/train_recognition/images/._71507.png
#   inflating: data/train_recognition/images/76268.png
#   inflating: __MACOSX/data/train_recognition/images/._76268.png
#   inflating: data/train_recognition/images/28472.png
#   inflating: __MACOSX/data/train_recognition/images/._28472.png
#   inflating: data/train_recognition/images/134013.png
#   inflating: __MACOSX/data/train_recognition/images/._134013.png
#   inflating: data/train_recognition/images/61714.png
#   inflating: __MACOSX/data/train_recognition/images/._61714.png
#   inflating: data/train_recognition/images/27741.png
#   inflating: __MACOSX/data/train_recognition/images/._27741.png
#   inflating: data/train_recognition/images/36894.png
#   inflating: __MACOSX/data/train_recognition/images/._36894.png
#   inflating: data/train_recognition/images/19877.png
#   inflating: __MACOSX/data/train_recognition/images/._19877.png

# %%
# !ls
# Out:
# data  data.zip	__MACOSX  sample_data

# %%
import pandas as pd
import os

# %%
a = os.listdir("/content/data/train_recognition/images")

# %%
len(a)
# Out:
# 161700

# %%
data = pd.read_csv("/content/data/train_recognition/labels.csv")

# %%
data[data["text"].apply(
    lambda x : len(x.split())
    ) > 1]
# Out:
#             file_name            text   base_image
# 645           645.png       Дв адцать      1_4.JPG
# 4185         4185.png    догодался я.      3_3.JPG
# 4470         4470.png   своего полка.      3_4.JPG
# 4504         4504.png  в полисаднике,      3_4.JPG
# 4605         4605.png          ср. р.      3_4.JPG
# ...               ...             ...          ...
# 157042   9677_eng.png          do not  4_8_eng.jpg
# 157066   9701_eng.png          uder -  4_8_eng.jpg
# 157146   9781_eng.png    Film makers,  4_8_eng.jpg
# 160339  12975_eng.png    net working.  6_4_eng.jpg
# 160537  13173_eng.png      m rdering.  6_4_eng.jpg
#
# [2575 rows x 3 columns]

# %% [markdown]
# # Скачивание правильного датасета

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !unzip /content/drive/MyDrive/Датасет/train.zip

# %%
import json
import pandas as pd

# %%
with open("/content/train/labels.json", "r") as f:
    labels = json.load(f)
# Out:
# Mounted at /content/drive

# %%
file_name = list(labels.keys())

text = list(labels.values())

# %%
labels_csv = pd.DataFrame(dict(file_name = file_name, text = text))

# %%
labels_csv.to_csv("/content/train/labels.csv", index=False)

# %% [markdown]
# # Импорт

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
from torch.utils.data import Dataset
from torch.nn.utils.rnn import pad_sequence
from tqdm.notebook import tqdm
import numpy as np
import editdistance
from sklearn.model_selection import train_test_split
from collections import Counter
import cv2
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import clear_output
from torchvision import transforms
import os
import random
from PIL import Image, ImageDraw
import json
from IPython.display import clear_output

from matplotlib import pyplot as plt

# %% [markdown]
# #Разделим трейн датасет на обучающую и валидационную подвыборки

# %%
labels = pd.read_csv('/content/train/labels.csv')
labels_train, labels_val = train_test_split(labels, test_size=0.05, random_state=655)

# %%
labels.dropna()
# Out:
#        file_name                   text
# 0          0.jpg                   OZON
# 1          1.jpg     ЮРИДИЧЕСКИЕ УСЛУГИ
# 2          2.jpg                  САЛОН
# 3          3.jpg                КРАСОТЫ
# 4          4.jpg                  Sахар
# ...          ...                    ...
# 40238  40238.jpg               чай кофе
# 40239  40239.jpg       домашняя выпечка
# 40240  40240.jpg  ТРУБОЧКА со сгущёнкой
# 40241  40241.jpg         ТОРТ черничный
# 40242  40242.jpg          ВКУСНЫЙ О БЕД
#
# [40241 rows x 2 columns]

# %%
def process_image(img, n_w=256, n_h=64):
    w, h,_ = img.shape
    new_w = n_h
    new_h = int(h * (new_w / w))
    img = cv2.resize(img, (new_h, new_w))
    w, h,_ = img.shape
    
    if w < n_h:
        add_zeros = np.full((n_h-w, h,3), 0)
        img = np.concatenate((img, add_zeros))
        w, h,_ = img.shape
    
    if h < n_w:
        add_zeros = np.full((w, n_w-h,3), 0)
        img = np.concatenate((img, add_zeros), axis=1)
        w, h,_ = img.shape
        
    if h > n_w or w > n_h:
        dim = (n_w,n_h)
        img = cv2.resize(img, dim)

    return img

def replace_black_to_white(image):
    brown_lo = np.array([0,0,0])
    brown_hi = np.array([0,0,0])

    # Mask image to only select browns
    mask = cv2.inRange(image,brown_lo,brown_hi)

    # Change image to red where we found brown
    image[mask>0] = (255,255,255)
    return image

# %%
class ExtraLinesAugmentation:
    '''
    Add random black lines to an image
    Args:
        number_of_lines (int): number of black lines to add
        width_of_lines (int): width of lines
    '''

    def __init__(self, number_of_lines: int = 1, width_of_lines: int = 10):
        self.number_of_lines = number_of_lines
        self.width_of_lines = width_of_lines
      
    def __call__(self, img):
        draw = ImageDraw.Draw(img)
        for _ in range(self.number_of_lines):
            x1 = random.randint(0, np.array(img).shape[1]); y1 = random.randint(0, np.array(img).shape[0])
            x2 = random.randint(0, np.array(img).shape[1]); y2 = random.randint(0, np.array(img).shape[0])
            draw.line((x1, y1, x2 + 100, y2), fill=(100, 0, 0), width=self.width_of_lines)

        return img

# %%
def plot_loss_history(train_history, val_history, title='loss'):
    plt.figure()
    plt.title('{}'.format(title))
    plt.plot(train_history, label='train', zorder=1)
    
    points = np.array(val_history)
    steps = list(range(0, len(train_history) + 1, int(len(train_history) / len(val_history))))[1:]
    
    plt.scatter(steps, val_history, marker='+', s=180, c='orange', label='val', zorder=2)
    plt.xlabel('train steps')
    
    plt.legend(loc='best')
    plt.grid()

    plt.show()

# %% [markdown]
# ## 2. Зададим параметры обучения

# %%
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')


config_json = {
    "alphabet": ''' !"#%&\'()*+,-./0123456789:;=?\n@ABCDEFGHIJKLMNOPQRSTUVWXYZ[\\]_abcdefghijklmnopqrstuvwxyz|«»ЁАБВГДЕЖЗИЙКЛМНОПРСТУФХЦЧШЩЪЫЬЭЮЯабвгдежзийклмнопрстуфхцчшщъыьэюяё–№''',
    #"alphabet": """@(),-.012345:;?I[]БВГДЗИКМНОПРСТУабвгдежзийклмнопрстуфхцчшщыьэюяё""",
    "save_dir": "data/experiments/test",
    "num_epochs": 500,
    "image": {
        "width": 256,
        "height": 64
    },
    "train": {
        "root_path": "/content/train/images",
        "batch_size": 64
    },
    "val": {
        "root_path": "/content/train/images",
        "batch_size": 128
    }
}

# %%
def process_row(text):
    # text = text.replace(' ', '|')
    text = list(text)
    for i in range(len(text)):
        if text[i] not in config_json['alphabet']:
            text[i] = '@'
    return " ".join(text)
def prepare_labels(path):
    lines = [line.rstrip() for line in open(path)]
    arr = []
    for line in lines:
        arr.append([line.split('\t')[0], line.split('\t')[1]])
    return arr

# %% [markdown]
# ## 3. Теперь определим класс датасета (torch.utils.data.Dataset) и другие вспомогательные функции

# %%
def black2white(image):
    lo=np.array([0,0,0])

    hi=np.array([0,0,0])

    mask = cv2.inRange(image, lo, hi)

    image[mask>0]=(255,255,255)

    return image

# %%
# функция которая помогает объединять картинки и таргет-текст в батч
def collate_fn(batch):
    images, texts, enc_texts = zip(*batch)
    images = torch.stack(images, 0)
    text_lens = torch.LongTensor([len(text) for text in texts])
    enc_pad_texts = pad_sequence(enc_texts, batch_first=True, padding_value=0)
    return images, texts, enc_pad_texts, text_lens
def collate_fn_val(batch):
    images, texts, enc_texts = zip(*batch)
    images = torch.stack(images, 0)
    text_lens = torch.LongTensor([len(text) for text in texts])
    enc_pad_texts = pad_sequence(enc_texts, batch_first=True, padding_value=0)
    return images, texts, enc_pad_texts, text_lens


def get_data_loader(
    transforms, df, root_path, tokenizer, batch_size, drop_last, config, train, shuffle=False
):
    dataset = OCRDataset(df, root_path, tokenizer, config, train, transforms)
    data_loader = torch.utils.data.DataLoader(
        dataset=dataset,
        collate_fn=collate_fn,
        batch_size=batch_size,
        num_workers=4,
        shuffle=shuffle
    )
    return data_loader

def get_data_loader_val(
    transforms, df, root_path, tokenizer, batch_size, drop_last, config, train, shuffle=False
):
    dataset = OCRDataset(df, root_path, tokenizer, config, train, transforms)
    data_loader = torch.utils.data.DataLoader(
        dataset=dataset,
        collate_fn=collate_fn_val,
        batch_size=batch_size,
        num_workers=4,
        shuffle=shuffle
    )
    return data_loader

def prepare_val_image(image, transform1, transform2):
    image3 = image.astype(np.uint8)
    image3 = Image.fromarray(image3)
    image3 = transform1(image3)
    image3 = np.array(image3).astype(np.int64)
    image3 = transform2(image3)
    return image3
class OCRDataset(Dataset):
    def __init__(self, df, root_path, tokenizer, config, train=False, transform=None):
        super().__init__()
        self.transform = transform
        self.config = config
        self.df = df
        self.data_len = len(self.df)
        self.train = train
        self.train_transform = transforms.Compose([
            ExtraLinesAugmentation(number_of_lines=3,
                                   width_of_lines=8),                         
            transforms.RandomAffine(degrees=0,
                                    scale=(0.935, 0.935),
                                    fillcolor=0),
            transforms.RandomCrop((self.config['image']['height'], self.config['image']['width'])),
            transforms.RandomRotation(degrees=(-12, 12),
                                      fill=255),])
        self.img_paths = []
        self.texts = []
        for i in range(self.data_len):

            if type(self.df['text'].iloc[i]) == float:
                continue

            self.img_paths.append(os.path.join(root_path, self.df['file_name'].iloc[i]))
            self.texts.append(self.df['text'].iloc[i])

        print(self.texts)
        self.enc_texts = tokenizer.encode(self.texts)

        self.data_len = len(self.texts)

    def __len__(self):
        return self.data_len

    def __getitem__(self, idx):
        img_path = self.img_paths[idx]
        text = self.texts[idx]
        enc_len = 32
        enc_text = self.enc_texts[idx][:enc_len]
        enc_text = enc_text + [0] * (enc_len - len(enc_text))
        enc_text = torch.LongTensor(enc_text)
        # image = black2white(cv2.imread(img_path))
        image = cv2.imread(img_path)

        if self.train:
            #image = self.blots(image)
            image = process_image(image,
                                  int(self.config['image']['width'] * 1.05),
                                  int(self.config['image']['height'] * 1.05))
            
            image = image.astype(np.uint8)
            image = Image.fromarray(image)
            image = self.train_transform(image)
            image = np.array(image).astype(np.int64)
        else:
            image = process_image(image, self.config['image']['width'], self.config['image']['height'])
        if self.transform is not None:
            image = self.transform(image)
        if self.train:
            image = image ** (random.random() * 0.7 + 0.6)
        if self.train == False:
            return image, text, enc_text
        else:
            return image, text, enc_text


class AverageMeter:
    """Computes and stores the average and current value"""
    def __init__(self):
        self.reset()

    def reset(self):
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %% [markdown]
# ## 4. Здесь определен Токенайзер - вспопогательный класс, который преобразует текст в числа

# %%
CTC_BLANK = '<BLANK>'

def get_char_map(alphabet):
    """Make from string alphabet character2int dict.
    Add BLANK char fro CTC loss and OOV char for out of vocabulary symbols."""
    char_map = {value: idx + 1 for (idx, value) in enumerate(alphabet)}
    char_map[CTC_BLANK] = 0
    return char_map


class Tokenizer:
    """Class for encoding and decoding string word to sequence of int
    (and vice versa) using alphabet."""

    def __init__(self, alphabet):
        self.char_map = get_char_map(alphabet)
        self.rev_char_map = {val: key for key, val in self.char_map.items()}

    def encode(self, word_list):
        """Returns a list of encoded words (int)."""
        enc_words = []
        for word in word_list:
            # print(word)
            enc_words.append(
                [self.char_map[char] if char in self.char_map
                 else 1
                 for char in word]
            )
        return enc_words

    def get_num_chars(self):
        return len(self.char_map)

    def decode(self, enc_word_list):
        """Returns a list of words (str) after removing blanks and collapsing
        repeating characters. Also skip out of vocabulary token."""
        dec_words = []
        for word in enc_word_list:
            word_chars = ''
            for idx, char_enc in enumerate(word):
                # skip if blank symbol, oov token or repeated characters
                if (
                    char_enc != self.char_map[CTC_BLANK]
                    # idx > 0 to avoid selecting [-1] item
                    and not (idx > 0 and char_enc == word[idx - 1])
                ):
                    word_chars += self.rev_char_map[char_enc]
            dec_words.append(word_chars)
        return dec_words
    def decode_after_beam(self, enc_word_list):
        """Returns a list of words (str) after removing blanks and collapsing
        repeating characters. Also skip out of vocabulary token."""
        dec_words = []
        for word in enc_word_list:
            word_chars = ''
            for idx, char_enc in enumerate(word):
                word_chars += self.rev_char_map[char_enc]
            dec_words.append(word_chars)
        return dec_words

# %% [markdown]
# ## 5. Accuracy в качестве метрики
#
# Accuracy измеряет долю предсказанных строк текста, которые полностью совпадают с таргет текстом.

# %%
def get_accuracy(y_true, y_pred):
    scores = []
    for true, pred in zip(y_true, y_pred):
        scores.append(true == pred)
    avg_score = np.mean(scores)
    return avg_score

# %% [markdown]
# ## 6. Аугментации
#
# Здесь мы задаем базовые аугментации для модели. Вы можете написать свои или использовать готовые библиотеки типа albumentations

# %%
class Normalize:
    def __call__(self, img):
        img = img.astype(np.float32) / 255
        return img


class ToTensor:
    def __call__(self, arr):
        arr = torch.from_numpy(arr)
        return arr


class MoveChannels:
    """Move the channel axis to the zero position as required in pytorch."""

    def __init__(self, to_channels_first=True):
        self.to_channels_first = to_channels_first

    def __call__(self, image):
        if self.to_channels_first:
            return np.moveaxis(image, -1, 0)
        else:
            return np.moveaxis(image, 0, -1)


class ImageResize:
    def __init__(self, height, width):
        self.height = height
        self.width = width

    def __call__(self, image):
        image = cv2.resize(image, (self.width, self.height),
                           interpolation=cv2.INTER_LINEAR)
        return image



def get_train_transforms(height, width):
    transforms = torchvision.transforms.Compose([
        #ImageResize(height, width),
        
        MoveChannels(to_channels_first=True),
        Normalize(),
        ToTensor()
    ])
    return transforms


def get_val_transforms(height, width):
    transforms = torchvision.transforms.Compose([
        #ImageResize(height, width),
        MoveChannels(to_channels_first=True),
        Normalize(),
        ToTensor()
    ])
    return transforms

# %% [markdown]
# ## 7. Здесь определяем саму модель - CRNN
#
# Подробнее об архитектуре можно почитать в статье https://arxiv.org/abs/1507.05717

# %%
def get_resnet34_backbone(pretrained=True):
    m = torchvision.models.resnet34(pretrained=True)
    input_conv = nn.Conv2d(3, 64, 7, 1, 3)
    blocks = [input_conv, m.bn1, m.relu,
              m.maxpool, m.layer1, m.layer2, m.layer3]
    return nn.Sequential(*blocks)
def get_resnet50_backbone(pretrained=True):
    m = torchvision.models.resnet50(pretrained=True)
    input_conv = nn.Conv2d(3, 64, 7, 1, 3)
    blocks = [input_conv, m.bn1, m.relu,
              m.maxpool, m.layer1, m.layer2, m.layer3]
    return nn.Sequential(*blocks)

class BiLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, dropout=0.1):
        super().__init__()
        self.lstm = nn.LSTM(
            input_size, hidden_size, num_layers,
            dropout=dropout, batch_first=True, bidirectional=True)

    def forward(self, x):
        out, _ = self.lstm(x)
        return out

# %%
class CRNN_RESNET(nn.Module):
    def __init__(
        self, number_class_symbols, out_len=32
    ):
        super().__init__()
        self.feature_extractor = get_resnet34_backbone(pretrained=True)
        # веса resnet34 получаются из этого гитхаба https://github.com/lolpa1n/digital-peter-ocrv 
        #self.feature_extractor.load_state_dict(torch.load('../input/ocr-resnet/resnet_ocr.pt')) 
        self.avg_pool = nn.AdaptiveAvgPool2d(
            (512, out_len))
        self.bilstm = BiLSTM(512, 256, 2)
        self.classifier = nn.Sequential(
            nn.Linear(512, 256),
            nn.GELU(),
            nn.Dropout(0.1),
            nn.Linear(256, number_class_symbols)
        )
    def forward(self, x, return_x=False):
        feature = self.feature_extractor(x)
        b, c, h, w = feature.size()
        feature = feature.view(b, c * h, w)
        feature = self.avg_pool(feature)
        feature = feature.transpose(1, 2)
        out = self.bilstm(feature)
        #print(x.shape)
        out = self.classifier(out)
        

        x1 = nn.functional.log_softmax(out, dim=2).permute(1, 0, 2)
        if return_x:
            return x1, out
        else:
            return x1

# %% [markdown]
# ## 8. Переходим к самому скрипту обучения - циклы трейна и валидации

# %%
from copy import deepcopy

def val_loop(data_loader, model, criterion, tokenizer, device):
    acc_avg = AverageMeter()
    loss_avg = AverageMeter()
    error_chars = 0
    criterion2 = nn.CrossEntropyLoss()
    total_string = 0
    ctc_weight = 0.9
    for images, texts, enc_pad_texts, text_lens in tqdm(data_loader):
        batch_size = len(texts)
        enc_pad_texts2 = deepcopy(enc_pad_texts.view(-1)).cuda()
        text_preds, output, output2 = predict(images, model, tokenizer, device, return_output=True)
        output_lenghts = torch.full(
            size=(output.size(1),),
            fill_value=output.size(0),
            dtype=torch.long
        )

        loss1 = criterion(output, enc_pad_texts, output_lenghts, text_lens).mean()
        output2 = output2.view(output2.shape[0] * output2.shape[1], output2.shape[2])
        loss2 = criterion2(output2,
                           enc_pad_texts2)
        loss = ctc_weight * loss1 + (1.0 - ctc_weight) * loss2
        loss_avg.update(loss.item(), batch_size)
        for i in range(batch_size):
            total_string += 1
            error_chars += (editdistance.eval(text_preds[i], texts[i]) / len(texts[i]))
            '''
            if text_preds[i] != texts[i]:
                print('----------------')
                print(f'true: {texts[i]}')
                print(f'pred: {text_preds[i]}')
            '''
        acc_avg.update(get_accuracy(texts, text_preds), batch_size)
    print(f"Val loss average: {loss_avg.avg}")
    print(f'Validation, acc: {acc_avg.avg:.4f}')
    print(f"CER: {error_chars / total_string * 100}%")
    #loss, cer, acc
    return loss_avg.avg, error_chars / total_string, acc_avg.avg

def train_loop(data_loader, model, criterion, optimizer, epoch, train_history=[]):
    loss_avg = AverageMeter()
    model.train()
    criterion2 = nn.CrossEntropyLoss()
    ctc_weight = 0.9
    i = 0
    for images, texts, enc_pad_texts, text_lens in tqdm(data_loader):
        model.zero_grad()
        images = images.to(DEVICE)
        enc_pad_texts2 = deepcopy(enc_pad_texts.view(-1)).cuda()
        batch_size = len(texts)
        output, output2 = model(images, True)
        output_lenghts = torch.full(
            size=(output.size(1),),
            fill_value=output.size(0),
            dtype=torch.long
        )
        #print(output.permute(1, 0, 2).shape, enc_pad_texts.shape)
        #enc_pad_texts2 = []
        #second_loss = criterion2(output.permute(1, 0, 2), enc_pad_texts)
        enc_pad_texts = enc_pad_texts.flatten()  # make 1dim, the doc says we can do it
        enc_pad_texts = enc_pad_texts[enc_pad_texts != 0]  # drop blank dims

        loss1 = criterion(output, enc_pad_texts, output_lenghts, text_lens).mean()#(criterion(output, enc_pad_texts, output_lenghts, text_lens).mean() + second_loss) / 2 
        output2 = output2.view(output2.shape[0] * output2.shape[1], output2.shape[2])
        loss2 = criterion2(output2, enc_pad_texts2)
        loss = ctc_weight * loss1 + (1.0 - ctc_weight) * loss2    
        loss_avg.update(loss.item(), batch_size)
        train_history.append(loss.item())
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 2)
        optimizer.step()
        if i % 100 == 0:
            print('train_loss =', loss)
        i += 1
    for param_group in optimizer.param_groups:
        lr = param_group['lr']
    print(f'\nEpoch {epoch}, Loss: {loss_avg.avg:.5f}, LR: {lr:.7f}')
    return loss_avg.avg, train_history


def predict(images, model, tokenizer, device, return_output=False):
    model.eval()
    images = images.to(device)
    #print(images.shape)
    with torch.no_grad():
        output, output2 = model(images, True)
    #output = process_output(output)
    pred = torch.argmax(output.detach().cpu(), -1).permute(1, 0).numpy()
    text_preds = tokenizer.decode(pred)
    if return_output:
        return text_preds, output, output2
    else:
        return text_preds


def get_loaders(tokenizer, config, labels_train, labels_val):
    train_transforms = get_train_transforms(
        height=config['image']['height'],
        width=config['image']['width']
    )
    train_loader = get_data_loader(
        df=labels_train,
        root_path=config['train']['root_path'],
        transforms=train_transforms,
        tokenizer=tokenizer,
        batch_size=config['train']['batch_size'],
        drop_last=True,
        config=config,
        train=True,
        shuffle=True

    )
    val_transforms = get_val_transforms(
        height=config['image']['height'],
        width=config['image']['width']
    )
    val_loader = get_data_loader_val(
        df=labels_val,
        transforms=val_transforms,
        root_path=config['val']['root_path'],
        tokenizer=tokenizer,
        batch_size=config['val']['batch_size'],
        drop_last=False,
        config=config,
        train=False,
        shuffle=False
    )
    return train_loader, val_loader

# %%
labels.iloc[24928]
# Out:
# file_name    24928.jpg
# text           Сервисы
# Name: 24928, dtype: object

# %%
tokenizer = Tokenizer(config_json['alphabet'])
os.makedirs(config_json['save_dir'], exist_ok=True)
train_loader, val_loader = get_loaders(tokenizer, config_json, labels_train, labels_val)
# Out:
# ['alamy', "IT'S GOOD TO BE", '09.10.2019 г.', 'EAT Drink and BE MARRIED', 'Е ЦЕНЫ !!!', 'Мир детства', 'ДЕФИБРИЛЛЯТОР', 'Мос.', 'Доставка', 'ДУША ОБЯЗАНА ТРУДИТЬСЯ', 'АКВА', 'НИКТО НЕ ИДЕАЛЕН КРОМЕ МЕНЯ', 'Юлия', 'ВЫИГРЫВАЙ ПРИЗЫ!', 'выдали', 'PERFETTO PLUS SIZE', 'logo', 'прости меня!', '14 дней', 'АРИФМЕТКА', 'ВЫДАЧА ВОДИТЕЛЬСКИХ УДОСТОВЕРЕНИЙ', 'ROOTS', 'STRAIGHT TALK', 'ул. 8Марта 73', 'Zakaz@6', 'Не открывайте дверь ногами!', 'С ДОБРЫМ УТРОМ! БЕСИШЬ МЕНЯ', 'ЗДРА ВОМЫ СЛИЕ', 'Lounge', 'выглядит лучшая в мире мама', 'РОССЕЛЬХОЗБАНК 0.6', 'TRI', 'л я кислота', 'Институт дерматологии и косметоло', 'Код', 'УКРАiНА', 'ВЕТЫ', 'Арт.4006 Размер 35х37 см.', 'обжарка: dark', 'ШАМПАНСЬКИХ ВИН', 'SUSSIG', 'КУРСЫ АНГЛИСЙСКОГО ЯЗЫКА', 'Блюдо Кол-во Сумма', 'Банда невесты!', 'ХИМТОРГ', 'ХЕРСОН', 'ВСЕ О ГРУЗОВИКАХ - TRUCKSPLANET', 'ФАЙНА ТУСА', 'САЛОН S TET', 'ПЛОЩАДЬ СЛАВЫ МЕМОРИАЛЬНЫЙ КОМПЛЕКС', 'Русская Птица', 'Коммерческая', 'ЧЕРНОЗЕМЬЕ', 'номер авто', 'РИВ ГОШ МАСТЕР ТОНА', 'МАСКИ на резинках трехслойные', '31254', 'Virus! https:', 'alev trans', 'горк', 'ул. Луначарского', 'DO.BRO COFFEE', '9,11,12 ИЮЛЯ 19:00', 'ЮНЬ', '140 заданий', 'ТОРТЫ ПИРОЖНЫЕ', 'фолы 8', 'Выходн', 'жизнь движени', 'ИНСТИТУТ ГРИППА ИМ', 'Зеркало', 'ELIVAN', 'Лазоревый проезд, 15', 'ББР БАНК', 'Хайп', 'ДЕТЕЙ ЗАБАВЛЯТЬ, НА САНКАХ КАТАТЬ!', 'С днём рождения, моя хулиганка!', 'КАБЕРНЕ СОВИНЬОН', 'Обстановка', 'СПЛАВЛЯТЬСЯ ПО ЛЕДНИКОВЫМ ОЗЕРАМ', 'ДОРОШЕНКО Олег Яковлевич ДИРЕКТОР', 'РЕАЛЬНЫЕ ДОСТИЖЕНИЯ ЛИЧНОСТИ', '-10', '43 1', 'мы будем', 'автомобили', 'БАНК СОЮ', 'Orange спортив', 'ЗАМОК СЛАДОСТЕЙ', 'АЗБУКА ВКУС', 'смелых', 'Это эл тробус.', '13 26 МАРТА 1900', 'FRANK', 'ПРОИГРЫШ -', '1.00 4.00', 'БАННЕР СПБ МИР УКРЫВНЫХ МАТЕРИАЛОВ', 'FAIRY TALES', 'СИТУАЦИИ лети в Питер!', 'И-8', 'ВОДКА', 'Ремонт iPhone, iPad', 'December', 'СЛИШКОМ ЧЕРНЫЙ ЮМОР', 'паспорт рекламного места', 'лучший папа', 'КОРОТКО О СЕБЕ: РЕКОМЕНДУЮ', '211,1 2009', 'СОЦИАЛЬНО-ЭКОЛОГИЧЕСКИЙ БАНКОВСКИЙ ХОЛДИНГ', 'MENU', 'идки', 'ДА', 'КАФЕ ИЛЛАРИОН', 'ductiongro', 'ЛЯХ', 'ПРОКУРАТУРА', 'Аварийное вскрытие сейфов', 'УЧЕБНОЕ ПОСОБИЕ', 'ун 968', 'ОБОИ', 'ПРАВИЛА Нашей Семьи', 'КАК СДЕЛАТЬ НАДПИСЬ НА ШАРЕ', '100sp.ru', 'S T U', 'фрукты продукты', 'Магазин', 'КОМПАНИЯ', 'ДАААМ!', 'МОЛЛЮСКИ MOLLUSKA 8 видов', '824 77', '1500', 'ПОЧТА ОССИИ', 'Кабинет 1', 'reaky Blinders', 'ИЩУ И КУПЛЮ КВАРТИРУ', 'А ТЫ НИЧЁ ТАК!', 'УГОЛОК ПОТРЕБИТЕЛ', 'КАБИНЕТ ИЗОБРАЗИТЕЛЬНОГО ИСКУССТВА', 'Т тьяна и Повел', 'пицца паста суши', 'М.И. Кутузов', 'RENDEZNOUS', 'НЕПРЕРЫВКА ДРАЧЕНИНО', 'Кофе зёрна', 'Скинулись по рублю', 'МИРБИР', 'В. Жиганов', 'B I G BOSS', 'Majestic Olympic Homeric', 'SA', 'Хулиган, Я ТЕБЯ', 'ПРОСПЕКТ ВЕРНАНДСКОГО', '1 14 0', 'ООО ПРОИЗВОДСТВЕННОЕ ОБЪЕДИНЕНИЕ КОМПАС', 'NOW FREE', 'ФОРТ', 'ДОМ ДЕСЕРТОВ', 'улица БИРЮЗОВАЯ 10А', 'кабинетъ', 'ОТПЕЧАТАТЬ НАКСЕРИТЬ ПЕРЕКАТАТЬ КСЕРОКОПИРНУТЬ', 'МЕТАЛЛ', 'ЛЮБАVА', 'ЗАЩИТА ОТ ЛЕТАЮЩИХ МИКРОБОВ', 'BEST', 'БелПресса', 'ДИСКАВЕРИ show', 'Олександров Олександр Петрович', 'Time to drink BEER', '18а', 'заместитель руководителя отделения', 'FANAGO', 'Часть 3', 'Уксус яблочный 6', 'ПРАВДА СЕВЕРА ОБЛАСТНАЯ ГАЗЕТА', 'Мо', 'TABOO', 'АТМОСФЕРА', '339', 'школу', 'Мусоропровод должен быть исправен', '440 руб.', 'Фамилия Имя Отчество 12.04.1985- 01.10.2001', 'Pedant.ru РЕМОНТ СМАРТФОНОВ', 'МЯУ', 'ДОБРЫНИНСКИЙ', 'Вкус', 'профессор Алексан Васильевич ЧАЯНОВ', 'FIESTA', 'KUCHEND HOME', 'Santini', 'это необходимо знать!', 'уважаемый президент! остановите', 'КАЗНА', 'КУПЛЮ', '11 часть', '30 мм', '35 000руб.', 'КОФЕ ХАУЗ', 'RICH BIT', 'ДЕТСКАЯ ЭНЦИКЛОПЕДИЯ РОСМЭН', 'ТЕХНИКА ДЛ', 'bukvi_viveski.ru Чертановская 9, корп. 3', 'Расплата на дороге', 'Kid', 'АЛЕКСАНДР', 'пенное', 'зачем', 'Женился сам теперь не ной', 'ПЕЛАГЕЯ АЛЕКСАНДРОВНА 1899 - 06.01.1979', 'Inchcape', 'АВТОМАСЛА ЗАМЕ', 'ВСЕХ!', 'ДРЕВНЕМУ МАМОНТУ АГОДАР МАМОНТ', 'flyer online интернет-сервис заказа полиграфии', '041151', 'РЕСПУБЛИКА БАШКОРТОСТАН', 'Вираж рекламная компания', 'рия иимства', 'СЕВЕРО-ВОСТОЧНЫЙ СТОМАТОЛОГИЧЕСКИЙ ЦЕ ...
# ['4 ноября', '22.00-4.00', 'Поле Чудес', 'МАГАЗИН SHOP', 'А ТЫ НИЧЁ ТАК', 'ГУЛIНА NAVORSKI ГУЛЬНАРА VIKTOR НАЛЫРАУНА', 'Назад Добавить карту Готово', 'ПМС', 'тлен', 'про дук ты', 'Chalkies 26 VECTOR ILLUSTRATIONS', 'Red Shoes', 'ПЕКАРНЯ ДОНЕР', 'Фальков гордимся!', 'И алга КАЗАНЬ', 'AT ME', 'АНИЧЕННОЙ ФРАХТ ЯНАО', 'винный бар + магазин', 'и пусть весь мир ПОДОЖДЕТ!', 'секси', 'аккумуляторы рф', 'Виталий Данилюк Осенний снег', 'TaxiStart Партнёр Яндекс.Такси', 'ЛЕНТА ПОЭЗИИ', 'Star afe hit', 'ГОРОД-ГЕРОЙ НОВОРОССИЙСК', '1 000-00', 'Columbus', 'ТРИАЛ МАРКЕТ', 'РЕМОНТЪ ОДЕЖДЫ', '368,5', 'WILL BE MORE DISAPPOINTED', ',', 'девки Я свободен', 'мечел', 'Предложение', 'ОБРАЗОВАТЕЛЬНЫЕ ПРОЕКТЫ', 'не прислоняться', 'ЕКАРНЯ', 'министерство здравоохранения камчатского края', 'FUBAG РЕЗУЛЬТАТ ГАРАНТИРОВАН', '24 МОЙКА', 'РАК:', 'я первомайский', 'ИЮНЯ', 'ПЛАНЫ НА ДЕНЬ', 'ГБОУ ШКОЛА 1241', 'МОЛОКО цельное сгущенное с сахаром', 'Измайловская', 'защита отвага', '221', 'film', 'Участки', 'КАПЕЦ ТЫ СТАРА', 'BABY it s cold OutsidE', 'Кириши Kirishi', 'ТРОШИН СЕРГЕЙ менеджер', 'national tourism adminisration', 'мраморная крошка гранит изготовление', 'Имеешь право все послать!', 'al Di', 'АНТИК', 'ВЕДЁТСЯ ВИДЕНАБЛЮДЕНИЕ', 'ЖРЁШЬ?', 'CanStockPhoto.com - csp54006952', 'с разноуровневыми заданиями', 'мы - новая энергия страны', 'ВСЕ ИДЕТ', 'МОЛОДОСТЬ ВСЕ ПРОСТИТ', 'Новая жизнь', 'г. Пермь', 'ПЕКАРТИ', 'TRAining sessions', 'н и я е', 'ul. Czcionkowa', 'ШОКОЛАДЪ СПОРТЪ.', 'СУВЕНИРЫ ПОД РКИ', 'you', '1289', 'Как электромобиль, только автобус', 'туалет для девочек', 'если хоч шь', 'Дубравная Dubravnaya', 'Красное зеркало', 'улица Корабельная', 'СЧАСТЛИВОГ ЧЕГО ТАМ У ТЕБЯ', 'Заметки 31', 'ЦЕНТР ДЕЛОВЫХ КОНТАКТОВ', 'Go', 'СТРАХОВОЕ АГЕНСТВО', 'буквы', 'happy day', 'ШЕРЕМЕТЬЕВО SHEREMET YEVO', 'LEASE', '17 540 руб.', 'Конфеты по рецептуре "ПТИЧЬЕ МОЛОКО"', 'дизайн сантехника', 'L TOP', '100 EURO', '1939', 'Продавец-консультант Francesco Donni, Сеть магазинов', '01H 815 PA', 'ЭкспоДом деревянное домостроение xpdom.ru', 'круглый, гладкий и сладкий', '48,6 2011', 'ОКТЯБРЯ СУББОТА', 'votonia.ru детский интернет магазин', 'БЕЗ ПАНИКИ / Я ФЕЯ', '2020', 'ФУТБОЛЬНЫЙ МЯЧ', 'казанских дворах', 'ФОРТЕ ПИАНО', '05 06 07', 'НЕТ ВОЙНЕ', 'ГОД ПОЗАДИ- ВСЕ ВПЕРЕДИ', 'НЕ ВЛЕЗА убьет', 'CYBERNEIDER', 'auty.c', 'НОМЕРА ROOMS 101 - 104', 'переулок', 'МОХНАТЫЙ КРАБ', 'контрольное время удержания, дней', 'Е. П. Барухова', 'ПЛЮСЫ', 'ID 178563077 Pisotckii', '541234568908', 'АБВГДЕЖ', 'рали вали', 'Поставщик:', 'AP 084', 'ШИНОМОНТАЖ Gislaved', 'Кл', 'на всякий случай', 'Bang! Bang! Education', 'МИРНАЯ 18 УЛИЦА 12-22', 'Я ПОМНЮ КАК УВИДЕЛ ТЕБЯ', 'ТЫС. РУБ.', 'COVER HEADLINE', 'СВЕТОВЫЕ КОРОБА', 'Обучение', 'Добавьте свой текст или рисунок', '36 6', 'НЕМЕЦКИЙ ЦЕНТР ИМПЛАНТАЦИИ', 'обитаемый остров', 's', 'ДЕТСКИЕ СЕКЦИИ 4 ИДЕТ НАБОР', '44 СКИДКА', 'Ты круче, чем', '74-00-33', 'X', 'М Макдоналдс', 'Проза Поэта', 'oodji', 'YOUR LOGO HERE', 'ПРОДУКТИ', 'МУЖИК ЧТО НАДО', 'ЗУБНОЙ ВРАЧ', 'кассы', 'РЫБА', 'omlette', 'CMD анализы экспертного уровня', 'Е.Ю. ЧЕРНЫШЕВЪ ПОСТАВЩИКЪ ПРАЗДНИКОВЪ', 'размер 770 п.', '23 08 2017 17:38', 'Офис маркет', 'Бухгалтер Петрова Елена Ивановна', 'Ака МАТОЛ', 'вечiрка гiвно', 'Жизнь популярной писательницы', 'ГОРОДСКОЙ ЭЛЕКТРОБ', '1 ПРИШЁЛ УВИДЕЛ Победил', 'НХ', '0 1 2 3', 'НИВА', 'avery Zweckform', 'РАН', 'Остров Сокровищ', 'Мы варим кофе Свежей обжарки', 'УЛИЦА АЛОВСКАЯ 3', 'Основана 22 июля 1917 года', 'BUREVESTNIK MONTENEGRO', '43', 'ВИННЫЙ СУПЕРМАРКЕТ', 'ЭКЛЗ 0872002619 00000009 032793', 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ АМБК', 'KIEROWNIK', 'император ба', 'СТРОИТЕЛИ!', 'PRONTO PIZZA скидки', 'Форма одежды - "Новая"', 'Хачю женчинцу чтоб бил прадовец', 'ГУБКИН Fe', 'ОБЛАКОВШТАНАХ', 'ok', 'меню', 'АТЛАС', '422 424', 'Терапевтический кабинет', 'МГГЭУ', 'Мультимедийная постановка', '3 ОТДЕЛ УГИБДД', 'АПТЕКАРСКИЙ ОГОРОД', 'Банкротство физических лиц', 'ПИОN', 'С ВИДОМ А ПАРК', 'May WaveS Шрамы Dope', "СВIЖЕ М'ЯСО", 'Контур', 'ханами', '404', 'м202нк', 'С ...

# %%
tokenizer.get_num_chars()
# Out:
# 159

# %%
model = CRNN_RESNET(tokenizer.get_num_chars(), 32)
model.to(DEVICE)
model.eval()
# Out:
# CRNN_RESNET(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (5): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (avg_pool): AdaptiveAvgPool2d(output_size=(512, 32))
#   (bilstm): BiLSTM(
#     (lstm): LSTM(512, 256, num_layers=2, batch_first=True, dropout=0.1, bidirectional=True)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=512, out_features=256, bias=True)
#     (1): GELU(approximate=none)
#     (2): Dropout(p=0.1, inplace=False)
#     (3): Linear(in_features=256, out_features=159, bias=True)
#   )
# )

# %%
criterion = torch.nn.CTCLoss(blank=0, reduction='none', zero_infinity=True)
optimizer = torch.optim.AdamW(model.parameters(), lr=0.001,
                                  weight_decay=0.01)

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer=optimizer, mode='min', factor=0.5, patience=2)

# %%
best_cer = np.inf
best_loss = np.inf
best_epoch = 0
train_history = []
val_history = []
val_loop(val_loader, model, criterion, tokenizer, DEVICE)
for epoch in tqdm(range(config_json['num_epochs'])):
    print("num of epoch", epoch)
    loss_avg, train_history = train_loop(train_loader, model, criterion, optimizer, epoch, train_history)
    print('average_train_loss', loss_avg)
    val_loss_avg, cer_avg, acc_avg = val_loop(val_loader, model, criterion, tokenizer, DEVICE)
    val_history.append(val_loss_avg)
    scheduler.step(cer_avg)
    if cer_avg < best_cer:
        best_cer = cer_avg
        best_epoch = epoch
        best_loss = val_loss_avg
        model_save_path = os.path.join(
            config_json['save_dir'], f'model-{epoch}-{cer_avg:.4f}.ckpt')
        torch.save(model.state_dict(), '/content/' + model_save_path)
        print('Model weights saved')
    clear_output()
    for param_group in optimizer.param_groups:
        lr = param_group['lr']
    print(f'Current CER = {cer_avg}')
    print(f'Current loss = {val_loss_avg}')
    print(f'Current acc_avg = {acc_avg}')
    print(f'Current learning rate = {lr}')
    print('-' * 20)
    print(f'Best CER = {best_cer}')
    print(f'Best loss = {best_loss}')
    print(f'Best epoch = {best_epoch}')
    plot_loss_history(train_history, val_history)
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-70-9a8136045408> in <module>
#       4 train_history = []
#       5 val_history = []
# ----> 6 val_loop(val_loader, model, criterion, tokenizer, DEVICE)
#       7 for epoch in tqdm(range(config_json['num_epochs'])):
#       8     print("num of epoch", epoch)
#
# <ipython-input-64-2cc1bf12982a> in val_loop(data_loader, model, criterion, tokenizer, device)
#      10     for images, texts, enc_pad_texts, text_lens in tqdm(data_loader):
#      11         batch_size = len(texts)
# ---> 12         enc_pad_texts2 = deepcopy(enc_pad_texts.view(-1)).cuda()
#      13         text_preds, output, output2 = predict(images, model, tokenizer, device, return_output=True)
#      14         output_lenghts = torch.full(
#
# /usr/local/lib/python3.7/dist-packages/torch/cuda/__init__.py in _lazy_init()
#     215         # This function throws if there's a driver initialization error, no GPUs
#     216         # are found or any other error occurs
# --> 217         torch._C._cuda_init()
#     218         # Some of the queued calls may reentrantly call _lazy_init();
#     219         # we need to just return without initializing in that case.
#
# RuntimeError: No CUDA GPUs are available

# %%
# %%shell
# !git clone https://github.com/PaddlePaddle/PaddleOCR
# !pip install paddlepaddle-gpu pyclipper attrdict -qqq
# %cd PaddleOCR
# !pip install -e .
# Out:
# Cloning into 'PaddleOCR'...
# remote: Enumerating objects: 44836, done.
# remote: Counting objects: 100% (1119/1119), done.
# remote: Compressing objects: 100% (501/501), done.
# remote: Total 44836 (delta 727), reused 961 (delta 617), pack-reused 43717
# Receiving objects: 100% (44836/44836), 338.32 MiB | 17.08 MiB/s, done.
# Resolving deltas: 100% (31572/31572), done.
#      |████████████████████████████████| 394.0 MB 23 kB/s
#      |████████████████████████████████| 604 kB 61.3 MB/s
#      |████████████████████████████████| 394 kB 51.3 MB/s
# /content/PaddleOCR
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/PaddleOCR
# WARNING: Discarding file:///content/PaddleOCR. Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# ERROR: Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.

# %%
# !python3 -m pip install paddlepaddle-gpu
# !python3 -m pip install paddlepaddle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 112.5 MB 59 kB/s
# ...

# %%
# !wget https://paddleocr.bj.bcebos.com/dygraph_v2.0/multilingual/ru_mobile_v2.0_rec_infer.tar
# Out:
# --2022-10-30 04:40:09--  https://paddleocr.bj.bcebos.com/dygraph_v2.0/multilingual/ru_mobile_v2.0_rec_infer.tar
# Resolving paddleocr.bj.bcebos.com (paddleocr.bj.bcebos.com)... 103.235.46.61, 2409:8c04:1001:1002:0:ff:b001:368a
# Connecting to paddleocr.bj.bcebos.com (paddleocr.bj.bcebos.com)|103.235.46.61|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2734080 (2.6M) [application/x-tar]
# Saving to: ‘ru_mobile_v2.0_rec_infer.tar’
#
# ru_mobile_v2.0_rec_ 100%[===================>]   2.61M  4.12MB/s    in 0.6s
#
# 2022-10-30 04:40:11 (4.12 MB/s) - ‘ru_mobile_v2.0_rec_infer.tar’ saved [2734080/2734080]

# %%
# !gunzip "ru_mobile_v2.0_rec_infer.tar"
# Out:
# gzip: ru_mobile_v2.0_rec_infer.tar: unknown suffix -- ignored

# %%
# !tar -xf "ru_mobile_v2.0_rec_infer.tar"

# %%
# !mv inference.pdiparams inference.pdiparams.info inference.pdmodel /content/model

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/Датасет/train.zip
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
#   inflating: train/images/35343.jpg
#   inflating: train/images/35344.jpg
#   inflating: train/images/35345.jpg
#   inflating: train/images/35346.jpg
#   inflating: train/images/35347.jpg
#   inflating: train/images/35348.jpg
#   inflating: train/images/35349.jpg
#   inflating: train/images/3535.jpg
#   inflating: train/images/35350.jpg
#   inflating: train/images/35351.jpg
#   inflating: train/images/35352.jpg
#   inflating: train/images/35353.jpg
#   inflating: train/images/35354.jpg
#   inflating: train/images/35355.jpg
#   inflating: train/images/35356.jpg
#   inflating: train/images/35357.jpg
#   inflating: train/images/35358.jpg
#   inflating: train/images/35359.jpg
#   inflating: train/images/35360.jpg
#   inflating: train/images/35361.jpg
#   inflating: train/images/35362.jpg
#   inflating: train/images/35363.jpg
#   inflating: train/images/35364.jpg
#   inflating: train/images/35365.jpg
# ...

# %%
# !mv train /content

# %%
alphabet = ''' !"#%&\'()*+,-./0123456789:;=?\n@ABCDEFGHIJKLMNOPQRSTUVWXYZ[\\]_abcdefghijklmnopqrstuvwxyz|«»ЁАБВГДЕЖЗИЙКЛМНОПРСТУФХЦЧШЩЪЫЬЭЮЯабвгдежзийклмнопрстуфхцчшщъыьэюяё–№'''
alphabet = "\n".join(alphabet.split())

with open("/content/rus_dict.txt", "w") as f:
    f.write(alphabet)

# %%
# !mv /content/model .

# %%
# !cp "/content/train/images/20349.jpg" /content/train/imgs/20349.jpg

# %%
# !python3 tools/infer/predict_rec.py --image_dir="/content/train/images/20350.jpg" --rec_model_dir="model" --rec_image_shape='3, 48, 320' # --rec_char_dict_path="/content/rus_dict.txt"
# Out:
# E1030 05:02:13.822404   973 analysis_config.cc:95] Please compile with gpu to EnableGpu()
# [2022/10/30 05:02:13] ppocr INFO: In PP-OCRv3, rec_image_shape parameter defaults to '3, 48, 320', if you are using recognition model with PP-OCRv2 or an older version, please set --rec_image_shape='3,32,320
# [2022/10/30 05:02:13] ppocr INFO: Predicts of /content/train/images/20350.jpg:("'题绚妇者娇8汴题贿房就''原", 0.6721526980400085)

# %%
# !ls /content/model/inference.pdmodel
# Out:
# /content/model/inference.pdmodel
